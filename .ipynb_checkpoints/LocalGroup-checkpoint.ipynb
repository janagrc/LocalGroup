# %% [markdown]
# # Analysis of Local Group Dwarf Galaxy Characteristics

# %%
# importing python packages we need to use
import csv
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
#print the versions of each python package used
print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# csv==1.0
# numpy==1.18.1
# pandas==0.25.3
# seaborn==0.9.0

# %%
#Make the plots high res
plt.rcParams['figure.dpi']= 300

# %%
galaxies = pd.read_csv('./dwarfs.csv')

# %%
galaxies_rh_pc = pd.read_csv('./galaxies_rh_pc.csv')

# %% [markdown]
# ## Change M_* to M_star

# %%
galaxies.loc[galaxies['GalaxyName']== 'Antlia2', 'M_star'] = 0.88

# %%
galaxies.drop('M_*', axis=1, inplace=True)

# %% [markdown]
# ## Look at Data

# %%
#Look at the Pandas dataframe named galaxies
galaxies
# Out:
#      Unnamed: 0       GalaxyName  RA_hr  RA_min  RA_sec  Dec_deg  Dec_arcmin  \
# 0             0       #TheGalaxy   17.0    45.0    40.0    -29.0         0.0
# 1             1     #*CanisMajor    7.0    12.0    35.0    -27.0        40.0
# 2             2  SagittariusdSph   18.0    55.0    19.5    -30.0        32.0
# 3             3        TucanaIII   23.0    56.0    36.0    -59.0        36.0
# 4             4          DracoII   15.0    52.0    47.6     64.0        33.0
# ..          ...              ...    ...     ...     ...      ...         ...
# 138         138          HydrusI    2.0    29.0    33.3    -79.0        18.0
# 139         139         CarinaII    7.0    36.0    25.5    -57.0        59.0
# 140         140        CarinaIII    7.0    38.0    31.1    -57.0        53.0
# 141         141         CraterII   11.0    49.0    14.4    -18.0        24.0
# 142         142       AquariusII   22.0    33.0    55.5     -9.0        19.0
#
#      Dec_arcsec   EB-V    m-M  ...   r_apo_err2  v_apo_mean  v_apo_median  \
# 0          28.0  9.999  99.99  ...          NaN         NaN           NaN
# 1           0.0  0.264  14.29  ...          NaN         NaN           NaN
# 2          43.0  0.153  17.10  ...    12.227629  104.536117    105.278226
# 3           0.0  9.999  17.01  ...     1.745390   36.939552     37.089534
# 4          55.0  0.016  16.90  ...    26.110572   77.314244     77.777376
# ..          ...    ...    ...  ...          ...         ...           ...
# 138        32.0    NaN  17.20  ...    25.920137   73.949053     73.697460
# 139        57.0    NaN  17.79  ...    61.056593   49.882156     50.330522
# 140        59.0    NaN  17.22  ...   226.758301   61.517261     55.847231
# 141        47.0    NaN  20.35  ...     6.749871   80.577944     81.659607
# 142        39.0    NaN  20.16  ...  1039.606763  316.899251    276.923009
#
#       v_apo_std  n_halo_apo  n_halo_apo_err1  n_halo_apo_err2  \
# 0           NaN         NaN              NaN              NaN
# 1           NaN         NaN              NaN              NaN
# 2      8.764286    0.004338         0.000753         0.001042
# 3      3.743090    0.000098         0.000089         0.000177
# 4     12.929979    0.000521         0.000460         0.000959
# ..          ...         ...              ...              ...
# 138    9.908038    0.000494         0.000187         0.000267
# 139    7.637017    0.001654         0.001038         0.001686
# 140   28.095470    0.003703         0.003150         0.010406
# 141   19.234086    0.000411         0.000158         0.000361
# 142  205.953643    0.000142         0.000122         0.001051
#
#     ell_surf_log10_abs  min_dist_mw_or_m31  Closer_MW_M31
# 0                  NaN                 NaN            NaN
# 1                  NaN                 NaN            NaN
# 2            -2.325838           18.587576             MW
# 3            -2.318699           23.298941             MW
# 4            -2.330260           26.126576             MW
# ..                 ...                 ...            ...
# 138          -2.310180           25.741743             MW
# 139          -2.285622           37.296364             MW
# 140          -2.303074           29.180644             MW
# 141          -2.122559          116.471698             MW
# 142          -2.227840          105.169370             MW
#
# [143 rows x 184 columns]

# %%
#List the column names of the dataframe galaxies
list(galaxies.columns)
# Out:
# ['Unnamed: 0',
#  'GalaxyName',
#  'RA_hr',
#  'RA_min',
#  'RA_sec',
#  'Dec_deg',
#  'Dec_arcmin',
#  'Dec_arcsec',
#  'EB-V',
#  'm-M',
#  'm-M_err_pos',
#  'm-M_err_neg',
#  'vh(km/s)',
#  'Vmag',
#  'Vmag_err_pos',
#  'Vmag_err_neg',
#  'PA',
#  'e=1-b/a',
#  'muVo',
#  "rh(')",
#  'rh_err_pos',
#  'rh_err_neg',
#  'vsig_s_x',
#  'vsig_err_pos',
#  'vsig_err_neg',
#  'vrot_s',
#  'vrot_s_err_pos',
#  'vrot_s_err_neg',
#  'MHI',
#  'Data',
#  'Key',
#  'vsig_g',
#  'vsig_g_err_pos',
#  'vsig_g_err_neg',
#  'vrot_g',
#  'note',
#  'M-m',
#  'Notes',
#  'ra',
#  'dec',
#  'M_V',
#  'dist_kpc',
#  'M_dyn',
#  'vh_(km/s)_err',
#  'vsig_s_upper_limit',
#  'vsig_s_err',
#  'vh(km/s)_err',
#  'orb_pericenter',
#  'orb_apocenter',
#  'orb_eccentricity',
#  'orb_period',
#  'orb_period_type',
#  'orb_pericenter_ref',
#  'orb_pericenter_0.8',
#  'orb_apocenter_0.8',
#  'orb_eccentricity_0.8',
#  'tau_50',
#  'tau_90',
#  'vsig_s_ref',
#  'vsig_s_err_pos_ref',
#  'vsig_s_err_neg_ref',
#  'M_V_ref',
#  'rh_pc_ref',
#  'rh_pc_err_pos_ref',
#  'rh_pc_err_neg_ref',
#  'vh(km/s)_ref',
#  'dist_kpc_ref',
#  'refs',
#  'M_star',
#  'M_dyn_r_h',
#  'Other names',
#  'Morphology',
#  'dist_pc',
#  'dist_mpc',
#  'vsig_s_err_pos_x',
#  'vsig_s_err_neg_x',
#  'rh_pc',
#  'rh_pc_err_neg',
#  'rh_pc_err_pos',
#  'vsig_s_y',
#  'vsig_s_err_pos_y',
#  'vsig_s_err_neg_y',
#  'gal_interference_min',
#  'gal_interference_max',
#  'Galactic Interference Range',
#  'MHI_computed',
#  'MHI_source',
#  'MHI_type',
#  '1sigma',
#  'rh_subtable',
#  'MHI_method',
#  'npix',
#  'GUU',
#  'GRU',
#  'HUU',
#  'HRU',
#  'GNV',
#  'HNV',
#  'LIT',
#  '1sigma_GUU',
#  '1sigma_GRU',
#  '1sigma_HUU',
#  '1sigma_HRU',
#  '1sigma_GNV',
#  '1sigma_HNV',
#  'm-M_err',
#  'Vmag_err',
#  'vsig_s',
#  'vsig_err',
#  'MHI_mcconnachie',
#  'vsig_g_err',
#  'GalaxyType',
#  'A_V',
#  'b_100M',
#  'b_1G',
#  'f_10G',
#  'mean_logz',
#  'Disturber',
#  'D',
#  'Theta',
#  'RA',
#  'Dec',
#  'OtherName',
#  'Subgroup',
#  'mateo_1',
#  'mateo_b',
#  'mateo_l',
#  '[Fe/H]',
#  '[Fe/H]_err',
#  'sigma_[Fe/H]',
#  'sigma_[Fe/H]_err',
#  'Ref1_Mateo98_Tab6',
#  '12 + log(O/H)',
#  'log(O/H)_err',
#  '[N/O]',
#  '[N/O]_err',
#  'Ref2_Mateo98_Tab6',
#  'Notes_Mateo98_Tab6',
#  'l',
#  'b',
#  'V_LSR',
#  'V_GSR',
#  'V_LGSR',
#  'X',
#  'Y',
#  'Z',
#  'angle_from_l=0',
#  'angle_from_MW_plane',
#  'M_dyn_calculated',
#  'M_dyn_method',
#  'MHI/M_star',
#  'MHI/M_dyn',
#  'MHI/M_V',
#  'L_V',
#  'MHI/L_V',
#  'r_ell',
#  'ell_surf_dist',
#  'mw_dist',
#  'm31_dist',
#  'r_per_mean',
#  'r_per_median',
#  'r_per_std',
#  'r_per_err1',
#  'r_per_err2',
#  'v_per_mean',
#  'v_per_median',
#  'v_per_std',
#  'n_halo_peri',
#  'n_halo_peri_err1',
#  'n_halo_peri_err2',
#  'r_apo_mean',
#  'r_apo_median',
#  'r_apo_std',
#  'r_apo_err1',
#  'r_apo_err2',
#  'v_apo_mean',
#  'v_apo_median',
#  'v_apo_std',
#  'n_halo_apo',
#  'n_halo_apo_err1',
#  'n_halo_apo_err2',
#  'ell_surf_log10_abs',
#  'min_dist_mw_or_m31',
#  'Closer_MW_M31']

# %%
#Simple plot of the minimum distance to the Milky Way center or M31's center (whichever is closer)
#vs the neutral hydrogen (HI) mass, which might represent either a detected mass
#*or* the upper limit on the HI mass in the case of non-detections.
plt.scatter(galaxies['min_dist_mw_or_m31'],galaxies['MHI_computed'])
plt.yscale('log')
plt.xlabel('Radius [pc]')
plt.ylabel('M$_{HI}$ [M$_{\odot}$]')
# Out:
# Text(0, 0.5, 'M$_{HI}$ [M$_{\\odot}$]')

# %%
#HI mass limits are denoted by the MHI_type column
#This displays a subset of columns of the full dataframe
#You can see many of the MHI_computed values are upper limits

galaxies[['GalaxyName','MHI_computed','MHI_type']]
# Out:
#           GalaxyName  MHI_computed     MHI_type
# 0         #TheGalaxy           NaN          NaN
# 1       #*CanisMajor           NaN          NaN
# 2    SagittariusdSph    122.454082  upper_limit
# 3          TucanaIII     90.189022  upper_limit
# 4            DracoII     56.714447  upper_limit
# ..               ...           ...          ...
# 138          HydrusI    124.584324  upper_limit
# 139         CarinaII    220.814382  upper_limit
# 140        CarinaIII    101.226583  upper_limit
# 141         CraterII   3010.646100  upper_limit
# 142       AquariusII   1747.479171  upper_limit
#
# [143 rows x 3 columns]

# %% [markdown]
# ## Add in W50s for gas-containing dwarfs

# %%
W50s = pd.read_csv('./putman21_dwarf_files/gaseous_dwarf_lg.csv')

# %%
W50s
# Out:
#                 Name  RA (J2000)  DE (J2000)  Distance  sigDist          MHI  \
# 0                LMC      80.892     -69.756      51.0      2.0  460000000.0
# 1                SMC      13.187     -72.829      64.0      4.0  460000000.0
# 2              Leo T     143.721      17.051     409.0     27.0     280000.0
# 3            Phoenix      27.775     -44.445     415.0     19.0     120000.0
# 4           NGC 6822     296.238     -14.789     459.0     17.0  130000000.0
# 5            NGC 185       9.742      48.338     617.0     26.0     110000.0
# 6            IC 1613      16.200       2.118     755.0     42.0   65000000.0
# 7               LGS3      15.979      21.885     769.0     25.0     380000.0
# 8              IC 10       5.071      59.304     794.0     44.0   50000000.0
# 9              Leo A     149.858      30.746     798.0     44.0   11000000.0
# 10           NGC 205      10.092      41.685     824.0     27.0     400000.0
# 11      Pegasus dIrr     352.150      14.743     920.0     30.0    5900000.0
# 12               WLM       0.492     -15.461     933.0     34.0   61000000.0
# 13  Sagittarius dIrr     292.496     -17.681    1067.0     88.0    8800000.0
# 14          Aquarius     311.717     -12.848    1072.0     40.0    4100000.0
# 15          Antlia B     147.233     -25.990    1294.0     95.0     280000.0
# 16          NGC 3109     150.779     -26.160    1300.0     48.0  450000000.0
# 17            Antlia     151.017     -27.331    1349.0     62.0     730000.0
# 18          UGC 4879     139.008      52.840    1361.0     25.0     950000.0
# 19         Sextans B     150.000       5.332    1426.0     20.0   51000000.0
# 20         Sextans A     152.754      -4.693    1432.0     53.0   77000000.0
# 21             Leo P     155.438      18.088    1622.0    149.0     940000.0
# 22           HIZSS3B     105.121      -4.208    1675.0    108.0    2600000.0
# 23         HIZSS3(A)     105.121      -4.208    1675.0    108.0   14000000.0
# 24       ESO410-G005       3.883     -32.180    1923.0     35.0     730000.0
# 25           IC 5152     330.675     -51.296    1950.0     45.0   87000000.0
#
#         W50  Vhelio
# 0    80.064   262.0
# 1    90.000   146.0
# 2    19.545    38.0
# 3    16.484   -13.0
# 4    80.000   -55.0
# 5    36.029  -204.0
# 6    27.000  -232.0
# 7    21.429  -287.0
# 8    62.000  -348.0
# 9    19.000    24.0
# 10   37.913  -246.0
# 11   23.000  -180.0
# 12   53.000  -130.0
# 13   23.548   -79.0
# 14   23.000  -138.0
# 15   16.955   376.0
# 16  143.644   403.0
# 17   29.906   362.0
# 18   14.000   -29.0
# 19   40.032   304.0
# 20   44.742   324.0
# 21   19.780   264.0
# 22   28.022   323.0
# 23   54.161   288.0
# 24   33.438     0.0
# 25   84.774   122.0

# %%
#Rename the pandas dataframe column just to make the merge easier
W50s.rename(columns={'Name': 'GalaxyName'},inplace=True)

# %%
W50s.dtypes
# Out:
# GalaxyName     object
# RA (J2000)    float64
# DE (J2000)    float64
# Distance      float64
# sigDist       float64
# MHI           float64
# W50           float64
# Vhelio        float64
# dtype: object

# %%
galaxies.dtypes
# Out:
# Unnamed: 0              int64
# GalaxyName             object
# RA_hr                 float64
# RA_min                float64
# RA_sec                float64
#                        ...
# n_halo_apo_err1       float64
# n_halo_apo_err2       float64
# ell_surf_log10_abs    float64
# min_dist_mw_or_m31    float64
# Closer_MW_M31          object
# Length: 184, dtype: object

# %%
#Merge the two datasets, info about merging here: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
result = pd.merge(galaxies, W50s, on="GalaxyName", how="left")

# %%
list(result['GalaxyName'])
# Out:
# ['#TheGalaxy',
#  '#*CanisMajor',
#  'SagittariusdSph',
#  'TucanaIII',
#  'DracoII',
#  'Segue1',
#  'Reticulum2',
#  'CetusII',
#  'TriangulumII',
#  'UrsaMajorII',
#  'BootesII',
#  'SegueII',
#  'Willman1',
#  'ComaBerenices',
#  'TucanaIV',
#  'BootesIII',
#  'GrusII',
#  'LMC',
#  'TucanaV',
#  'TucanaII',
#  'SagittariusII',
#  'SMC',
#  'Bootes',
#  'Draco',
#  'UrsaMinor',
#  'HorologiumII',
#  'Horologium1',
#  'Eridanus3',
#  'Phoenix2',
#  'Sculptor',
#  'Sextans',
#  'ReticulumIII',
#  'IndusI',
#  'UrsaMajor',
#  'GrusI',
#  'Pictoris1',
#  'Carina',
#  'Hercules',
#  'HydraII',
#  'Fornax',
#  'LeoIV',
#  'CanesVenaticiII',
#  'LeoV',
#  'PiscesII',
#  'ColumbaI',
#  'PegasusIII',
#  'IndusII',
#  'CanesVenatici(I)',
#  'LeoII',
#  'LeoI',
#  '#Andromeda',
#  'M32',
#  'AndromedaIX',
#  'NGC205',
#  'AndromedaI',
#  'AndromedaXVII',
#  'AndromedaXXVII',
#  'AndromedaIII',
#  'AndromedaXXV',
#  'AndromedaXXVI',
#  'AndromedaV',
#  'AndromedaXI',
#  'AndromedaXIX',
#  'AndromedaXXIII',
#  'AndromedaXX',
#  'AndromedaXIII',
#  'AndromedaX',
#  'AndromedaXXI',
#  'CassiopeiaIII',
#  'NGC147',
#  'AndromedaXXX',
#  'AndromedaXIV',
#  'AndromedaXII',
#  'AndromedaXV',
#  'AndromedaII',
#  'NGC185',
#  'AndromedaXXIX',
#  'Triangulum',
#  'AndromedaXXIV',
#  'AndromedaVII',
#  'IC10',
#  'LacertaI',
#  'LGS3',
#  'AndromedaVI',
#  'AndromedaXXII',
#  'AndromedaXVI',
#  'AndromedaXXVIII',
#  'PerseusI',
#  'IC1613',
#  'Phoenix',
#  'EridanusII',
#  'NGC6822',
#  'Cetus',
#  'PegasusdIrr',
#  'LeoT',
#  'WLM',
#  'AndromedaXVIII',
#  'LeoA',
#  'Aquarius',
#  'Tucana',
#  'SagittariusdIrr',
#  'UGC4879',
#  'AntliaB',
#  'NGC3109',
#  'SextansB',
#  'Antlia',
#  'SextansA',
#  'HIZSS3(A)',
#  'HIZSS3B',
#  'LeoP',
#  'ESO410-G005',
#  'KKR25',
#  'NGC55',
#  'ESO294-G010',
#  'NGC300',
#  'IC5152',
#  'KKH98',
#  'UKS2323-326',
#  'KK258',
#  'KKR3',
#  'KKs3',
#  'GR8',
#  'UGC9128',
#  'UGC8508',
#  'IC3104',
#  'DDO125',
#  'UGCA86',
#  'DDO99',
#  'IC4662',
#  'DDO190',
#  'KKH86',
#  'NGC4163',
#  'DDO113',
#  'Antlia2',
#  'CetusIII',
#  'DESJ0225+0304',
#  'PictorII',
#  'VirgoI',
#  'HydrusI',
#  'CarinaII',
#  'CarinaIII',
#  'CraterII',
#  'AquariusII']

# %%
result[['GalaxyName','W50']]
# Out:
#           GalaxyName  W50
# 0         #TheGalaxy  NaN
# 1       #*CanisMajor  NaN
# 2    SagittariusdSph  NaN
# 3          TucanaIII  NaN
# 4            DracoII  NaN
# ..               ...  ...
# 138          HydrusI  NaN
# 139         CarinaII  NaN
# 140        CarinaIII  NaN
# 141         CraterII  NaN
# 142       AquariusII  NaN
#
# [143 rows x 2 columns]

# %%
#Check all the W50 values "made it" through the merge
result['W50'].count()
# Out:
# 10

# %%
#rename the result of the merge back to galaxies
galaxies = result

# %%
galaxies_shortnames = galaxies

# %% [markdown]
# ## Make csv output with names

# %%
#Select out the columns of interest from the list of all galaxy features
cols = ['GalaxyName','l','b','angle_from_l=0','angle_from_MW_plane','dist_pc','min_dist_mw_or_m31','orb_pericenter','orb_apocenter','orb_eccentricity','orb_period','rh(\')','rh_pc','M_V','ell_surf_dist','M_dyn','vsig_s','vrot_s','vsig_g','vrot_g','W50','muVo','vh(km/s)','tau_90','[Fe/H]','V_GSR','V_LSR','V_LGSR','MHI_computed','X','Y','Z']
LGcatalog = galaxies[cols]

# %%
d ={'GalaxyName':'Galaxy Name','l':'l','b':'b','angle_from_l=0':'Angle from l=0','angle_from_MW_plane':'Angle from MW plane','dist_pc': 'Distance','min_dist_mw_or_m31': 'Dist MW or M31, nearest','orb_pericenter': 'Orbit Pericenter','orb_apocenter': 'Orbit Apocenter','orb_eccentricity':'Orbit Eccentricity','orb_period': 'Orbit Period','rh(\')': 'Angular Radius','rh_pc':'Radius [pc]','M_V': 'V band Magnitude M$_{V}$','ell_surf_dist': 'Distance to LG surf','M_dyn': 'Estimated Dynamical Mass','vsig_s': 'Stellar Velocity Dispersion $\sigma_{star}$','vrot_s': 'Stellar Rotation Velocity $V_{rot,star}$','vsig_g': 'HI Velocity Dispersion $\sigma_{gas}$','vrot_g': 'HI Rotation Velocity $V_{rot,gas}$','W50':'W50','muVo': 'Surface Brightness $\mu_{V}$','vh(km/s)':'Heliocentric Velocity $v_{helio}$','tau_90':"Star Formation Timescale $\\tau_{90}$",'[Fe/H]':'Mean Metallicity $\\langle $[Fe/H]$\\rangle $','V_GSR':'Galactocentric Velocity $V_{GSR}$','V_LSR':'Local Std of Rest Velocity $V_{LSR}$','V_LGSR':'Local Group Std of Rest Velocity $V_{LGSR}$','MHI_computed':'HI Mass $M_{HI}$ (Detected or Limit)','X':'3D Position (X)','Y':'3D Position (Y)','Z':'3D Position (Z)'}
cols = ['l','b','angle_from_l=0','angle_from_MW_plane','dist_pc','min_dist_mw_or_m31','orb_pericenter','orb_apocenter','orb_eccentricity','orb_period','rh(\')','rh_pc','M_V','ell_surf_dist','M_dyn','vsig_s','vrot_s','vsig_g','vrot_g','muVo','vh(km/s)','tau_90','[Fe/H]','V_GSR','V_LSR','V_LGSR','MHI_computed','X','Y','Z']
cols = np.array([d[x] for x in cols])
LGcatalog = LGcatalog.rename(columns=d)

# %%
LGcatalog.to_csv('LocalGroupData.csv', index = False)

# %% [markdown]
# ## Replace dataframe column names with readable & descriptive names

# %%
#Select out the columns of interest from the list of all galaxy features
cols = ['l','b','angle_from_l=0','angle_from_MW_plane','dist_pc','min_dist_mw_or_m31','orb_pericenter','orb_apocenter','orb_eccentricity','orb_period','rh(\')','rh_pc','M_V','ell_surf_dist','M_dyn','vsig_s','vrot_s','vsig_g','vrot_g','W50','muVo','vh(km/s)','tau_90','[Fe/H]','V_GSR','V_LSR','V_LGSR','MHI_computed','X','Y','Z']
galaxies = galaxies[cols]

# %%
#Rename the columns to something more readable. 
#This should better identify what each column represents,
#but you may need more info about some to be able to interpret some of them.

d ={'l':'l','b':'b','angle_from_l=0':'Angle from l=0','angle_from_MW_plane':'Angle from MW plane','dist_pc': 'Distance','min_dist_mw_or_m31': 'Dist MW or M31, nearest','orb_pericenter': 'Orbit Pericenter','orb_apocenter': 'Orbit Apocenter','orb_eccentricity':'Orbit Eccentricity','orb_period': 'Orbit Period','rh(\')': 'Angular Radius','rh_pc':'Radius [pc]','M_V': 'V band Magnitude M$_{V}$','ell_surf_dist': 'Distance to LG surf','M_dyn': 'Estimated Dynamical Mass','vsig_s': 'Stellar Velocity Dispersion $\sigma_{star}$','vrot_s': 'Stellar Rotation Velocity $V_{rot,star}$','vsig_g': 'HI Velocity Dispersion $\sigma_{gas}$','vrot_g': 'HI Rotation Velocity $V_{rot,gas}$','W50':'FWHM of HI line','muVo': 'Surface Brightness $\mu_{V}$','vh(km/s)':'Heliocentric Velocity $v_{helio}$','tau_90':"Star Formation Timescale $\\tau_{90}$",'[Fe/H]':'Mean Metallicity $\\langle $[Fe/H]$\\rangle $','V_GSR':'Galactocentric Velocity $V_{GSR}$','V_LSR':'Local Std of Rest Velocity $V_{LSR}$','V_LGSR':'Local Group Std of Rest Velocity $V_{LGSR}$','MHI_computed':'HI Mass $M_{HI}$ (Detected or Limit)','X':'3D Position (X)','Y':'3D Position (Y)','Z':'3D Position (Z)'}
cols = ['l','b','angle_from_l=0','angle_from_MW_plane','dist_pc','min_dist_mw_or_m31','orb_pericenter','orb_apocenter','orb_eccentricity','orb_period','rh(\')','rh_pc','M_V','ell_surf_dist','M_dyn','vsig_s','vrot_s','vsig_g','vrot_g','W50','muVo','vh(km/s)','tau_90','[Fe/H]','V_GSR','V_LSR','V_LGSR','MHI_computed','X','Y','Z']
cols = np.array([d[x] for x in cols])
galaxies = galaxies.rename(columns=d)

# %%
galaxies.to_csv('LocalGroupData.csv', index = False)

# %% [markdown]
# ## Spearman Correlation Example

# %%
#Force the values to numeric (if the data type is otherwise a string, for example)
galaxies.apply(pd.to_numeric)
# Out:
#               l          b  Angle from l=0  Angle from MW plane      Distance  \
# 0    359.957486  -0.037920        0.042514             0.037920  9.954054e+20
# 1    238.785657  -7.399239      121.214343             7.399239  7.211075e+03
# 2      6.599240 -13.731162        6.599240            13.731162  2.630268e+04
# 3    316.218039 -57.291307       43.781961            57.291307  2.500000e+04
# 4     98.294235  42.879985       98.294235            42.879985  2.150000e+04
# ..          ...        ...             ...                  ...           ...
# 138  297.058245 -37.293968       62.941755            37.293968  2.760000e+04
# 139  268.079625 -16.318072       91.920375            16.318072  3.620000e+04
# 140  268.301071 -16.094271       91.698929            16.094271  2.780000e+04
# 141  282.546783  42.809367       77.453217            42.809367  1.175000e+05
# 142   56.009685 -52.644863       56.009685            52.644863  1.079000e+05
#
#      Dist MW or M31, nearest  Orbit Pericenter  Orbit Apocenter  \
# 0                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
# 2                  18.587576               NaN              NaN
# 3                  23.298941               2.0             33.0
# 4                  26.126576              19.0             62.0
# ..                       ...               ...              ...
# 138                25.741743              26.0           1029.0
# 139                37.296364              26.0            118.0
# 140                29.180644              28.0            106.0
# 141               116.471698              18.0            124.0
# 142               105.169370              95.0            190.0
#
#      Orbit Eccentricity  Orbit Period  ...  Heliocentric Velocity $v_{helio}$  \
# 0                   NaN           NaN  ...                                NaN
# 1                   NaN           NaN  ...                               87.0
# 2                   NaN           NaN  ...                              140.0
# 3                  0.86           0.7  ...                             -102.3
# 4                  0.53           NaN  ...                             -342.5
# ..                  ...           ...  ...                                ...
# 138                0.95          10.0  ...                               80.4
# 139                0.64          10.0  ...                              477.2
# 140                0.58          10.0  ...                              284.6
# 141                0.74           NaN  ...                               87.5
# 142                0.75           NaN  ...                              -71.1
#
#      Star Formation Timescale $\tau_{90}$  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 138                                   NaN
# 139                                   NaN
# 140                                   NaN
# 141                                   NaN
# 142                                   NaN
#
#      Mean Metallicity $\langle $[Fe/H]$\rangle $  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 138                                          NaN
# 139                                          NaN
# 140                                          NaN
# 141                                          NaN
# 142                                          NaN
#
#      Galactocentric Velocity $V_{GSR}$  Local Std of Rest Velocity $V_{LSR}$  \
# 0                                  NaN                                   NaN
# 1                          -115.289002                             71.295837
# 2                           172.923646                            148.362962
# 3                          -191.421092                           -109.165467
# 4                          -170.461213                           -329.986730
# ..                                 ...                                   ...
# 138                         -84.947393                             70.914111
# 139                         252.414541                            463.433635
# 140                          59.593891                            270.878485
# 141                         -72.443765                             85.098059
# 142                          43.102940                            -67.574417
#
#      Local Group Std of Rest Velocity $V_{LGSR}$  \
# 0                                            NaN
# 1                                    -112.842743
# 2                                     125.868057
# 3                                    -201.114951
# 4                                    -158.718921
# ..                                           ...
# 138                                  -114.516164
# 139                                   225.875325
# 140                                    32.647267
# 141                                  -134.753249
# 142                                    70.016393
#
#      HI Mass $M_{HI}$ (Detected or Limit)  3D Position (X)  3D Position (Y)  \
# 0                                     NaN    -5.441684e+16    -8.689645e+17
# 1                                     NaN    -2.012744e+00     6.141357e+00
# 2                              122.454082     5.475242e+00    -2.223882e+01
# 3                               90.189022     1.309821e+01    -1.943301e-01
# 4                               56.714447    -4.866071e+00    -7.847660e+00
# ..                                    ...              ...              ...
# 138                            124.584324     4.300265e+00     3.286463e+00
# 139                            220.814382    -8.267582e+00     1.847700e+01
# 140                            101.226583    -6.461796e+00     1.409456e+01
# 141                           3010.646100    -1.118846e+02     5.256772e+00
# 142                           1747.479171     9.923141e+01    -3.912581e+01
#
#      3D Position (Z)
# 0      -4.824639e+17
# 1      -3.198780e+00
# 2      -1.293396e+01
# 3      -2.129317e+01
# 4       1.941612e+01
# ..               ...
# 138    -2.706413e+01
# 139    -3.001145e+01
# 140    -2.307442e+01
# 141    -3.550294e+01
# 142    -1.626985e+01
#
# [143 rows x 31 columns]

# %%
#Calculate the Spearman correlation coefficients between every feature, pairwise
spearman_matrix = galaxies.corr(method ='spearman')

# %%
#look at the spearman matrix dataframe
spearman_matrix
# Out:
#                                                     l         b  \
# l                                            1.000000 -0.074334
# b                                           -0.074334  1.000000
# Angle from l=0                              -0.086127  0.257412
# Angle from MW plane                          0.198073  0.213052
# Distance                                    -0.214054  0.257443
# Dist MW or M31, nearest                     -0.211169  0.144520
# Orbit Pericenter                            -0.394335 -0.238752
# Orbit Apocenter                             -0.072037 -0.133935
# Orbit Eccentricity                           0.288788  0.048778
# Orbit Period                                 0.276504  0.066742
# Angular Radius                               0.035098 -0.112553
# Radius [pc]                                 -0.102769  0.139433
# V band Magnitude M$_{V}$                     0.284003 -0.205496
# Distance to LG surf                         -0.071870  0.157617
# Estimated Dynamical Mass                    -0.371429  0.542857
# Stellar Velocity Dispersion $\sigma_{star}$ -0.666886 -0.153897
# Stellar Rotation Velocity $V_{rot,star}$     0.411248  0.400704
# HI Velocity Dispersion $\sigma_{gas}$        0.101935 -0.106562
# HI Rotation Velocity $V_{rot,gas}$          -0.027111 -0.135555
# FWHM of HI line                             -0.066870  0.395139
# Surface Brightness $\mu_{V}$                 0.032685  0.000234
# Heliocentric Velocity $v_{helio}$            0.389915  0.235771
# Star Formation Timescale $\tau_{90}$        -0.138434  0.038905
# Mean Metallicity $\langle $[Fe/H]$\rangle $  0.036802 -0.360211
# Galactocentric Velocity $V_{GSR}$           -0.027207  0.256302
# Local Std of Rest Velocity $V_{LSR}$         0.375235  0.251366
# Local Group Std of Rest Velocity $V_{LGSR}$ -0.130419  0.159642
# HI Mass $M_{HI}$ (Detected or Limit)        -0.242054  0.197306
# 3D Position (X)                             -0.270339 -0.727885
# 3D Position (Y)                              0.267120 -0.060726
# 3D Position (Z)                             -0.498911  0.436200
#
#                                              Angle from l=0  \
# l                                                 -0.086127
# b                                                  0.257412
# Angle from l=0                                     1.000000
# Angle from MW plane                                0.003172
# Distance                                           0.118246
# Dist MW or M31, nearest                            0.029653
# Orbit Pericenter                                   0.049282
# Orbit Apocenter                                   -0.265142
# Orbit Eccentricity                                -0.481858
# Orbit Period                                      -0.190693
# Angular Radius                                    -0.107647
# Radius [pc]                                        0.027690
# V band Magnitude M$_{V}$                          -0.043926
# Distance to LG surf                               -0.121620
# Estimated Dynamical Mass                           0.200000
# Stellar Velocity Dispersion $\sigma_{star}$        0.153897
# Stellar Rotation Velocity $V_{rot,star}$           0.147628
# HI Velocity Dispersion $\sigma_{gas}$             -0.115255
# HI Rotation Velocity $V_{rot,gas}$                -0.424739
# FWHM of HI line                                   -0.054711
# Surface Brightness $\mu_{V}$                       0.064109
# Heliocentric Velocity $v_{helio}$                 -0.240977
# Star Formation Timescale $\tau_{90}$              -0.196882
# Mean Metallicity $\langle $[Fe/H]$\rangle $        0.146984
# Galactocentric Velocity $V_{GSR}$                 -0.278825
# Local Std of Rest Velocity $V_{LSR}$              -0.252054
# Local Group Std of Rest Velocity $V_{LGSR}$       -0.176639
# HI Mass $M_{HI}$ (Detected or Limit)               0.110675
# 3D Position (X)                                   -0.145828
# 3D Position (Y)                                    0.636414
# 3D Position (Z)                                    0.441875
#
#                                              Angle from MW plane  Distance  \
# l                                                       0.198073 -0.214054
# b                                                       0.213052  0.257443
# Angle from l=0                                          0.003172  0.118246
# Angle from MW plane                                     1.000000 -0.073559
# Distance                                               -0.073559  1.000000
# Dist MW or M31, nearest                                -0.012931  0.860233
# Orbit Pericenter                                       -0.143935  0.596109
# Orbit Apocenter                                        -0.014701  0.173022
# Orbit Eccentricity                                      0.227561 -0.580847
# Orbit Period                                           -0.390920 -0.291469
# Angular Radius                                         -0.055161 -0.574276
# Radius [pc]                                             0.024187  0.556972
# V band Magnitude M$_{V}$                                0.190122 -0.671371
# Distance to LG surf                                     0.104128  0.712039
# Estimated Dynamical Mass                                0.600000  0.942857
# Stellar Velocity Dispersion $\sigma_{star}$            -0.359092 -0.102598
# Stellar Rotation Velocity $V_{rot,star}$                0.439368  0.343258
# HI Velocity Dispersion $\sigma_{gas}$                  -0.080342  0.031822
# HI Rotation Velocity $V_{rot,gas}$                     -0.386332 -0.010167
# FWHM of HI line                                        -0.322190 -0.151976
# Surface Brightness $\mu_{V}$                           -0.092818 -0.555969
# Heliocentric Velocity $v_{helio}$                       0.189342  0.141724
# Star Formation Timescale $\tau_{90}$                   -0.030914 -0.281780
# Mean Metallicity $\langle $[Fe/H]$\rangle $            -0.021189  0.418910
# Galactocentric Velocity $V_{GSR}$                       0.121700  0.327821
# Local Std of Rest Velocity $V_{LSR}$                    0.195526  0.150348
# Local Group Std of Rest Velocity $V_{LGSR}$             0.034427  0.387152
# HI Mass $M_{HI}$ (Detected or Limit)                   -0.121744  0.874710
# 3D Position (X)                                        -0.342880 -0.192254
# 3D Position (Y)                                        -0.151511 -0.044468
# 3D Position (Z)                                         0.020131  0.356638
#
#                                              Dist MW or M31, nearest  \
# l                                                          -0.211169
# b                                                           0.144520
# Angle from l=0                                              0.029653
# Angle from MW plane                                        -0.012931
# Distance                                                    0.860233
# Dist MW or M31, nearest                                     1.000000
# Orbit Pericenter                                            0.737269
# Orbit Apocenter                                             0.672590
# Orbit Eccentricity                                         -0.147411
# Orbit Period                                               -0.305108
# Angular Radius                                             -0.536916
# Radius [pc]                                                 0.554856
# V band Magnitude M$_{V}$                                   -0.608151
# Distance to LG surf                                         0.898020
# Estimated Dynamical Mass                                    0.942857
# Stellar Velocity Dispersion $\sigma_{star}$                -0.102598
# Stellar Rotation Velocity $V_{rot,star}$                   -0.050114
# HI Velocity Dispersion $\sigma_{gas}$                      -0.058729
# HI Rotation Velocity $V_{rot,gas}$                         -0.215038
# FWHM of HI line                                            -0.164134
# Surface Brightness $\mu_{V}$                               -0.625856
# Heliocentric Velocity $v_{helio}$                           0.317009
# Star Formation Timescale $\tau_{90}$                       -0.425407
# Mean Metallicity $\langle $[Fe/H]$\rangle $                 0.399333
# Galactocentric Velocity $V_{GSR}$                           0.485892
# Local Std of Rest Velocity $V_{LSR}$                        0.325436
# Local Group Std of Rest Velocity $V_{LGSR}$                 0.511009
# HI Mass $M_{HI}$ (Detected or Limit)                        0.781502
# 3D Position (X)                                            -0.111305
# 3D Position (Y)                                            -0.088029
# 3D Position (Z)                                             0.212504
#
#                                              Orbit Pericenter  \
# l                                                   -0.394335
# b                                                   -0.238752
# Angle from l=0                                       0.049282
# Angle from MW plane                                 -0.143935
# Distance                                             0.596109
# Dist MW or M31, nearest                              0.737269
# Orbit Pericenter                                     1.000000
# Orbit Apocenter                                      0.694967
# Orbit Eccentricity                                  -0.279674
# Orbit Period                                        -0.095783
# Angular Radius                                      -0.413689
# Radius [pc]                                          0.249812
# V band Magnitude M$_{V}$                            -0.448434
# Distance to LG surf                                  0.394250
# Estimated Dynamical Mass                            -0.205196
# Stellar Velocity Dispersion $\sigma_{star}$          0.815789
# Stellar Rotation Velocity $V_{rot,star}$            -0.700000
# HI Velocity Dispersion $\sigma_{gas}$               -1.000000
# HI Rotation Velocity $V_{rot,gas}$                  -1.000000
# FWHM of HI line                                           NaN
# Surface Brightness $\mu_{V}$                        -0.069680
# Heliocentric Velocity $v_{helio}$                   -0.225959
# Star Formation Timescale $\tau_{90}$                -0.040905
# Mean Metallicity $\langle $[Fe/H]$\rangle $          0.218895
# Galactocentric Velocity $V_{GSR}$                   -0.007943
# Local Std of Rest Velocity $V_{LSR}$                -0.228634
# Local Group Std of Rest Velocity $V_{LGSR}$          0.134538
# HI Mass $M_{HI}$ (Detected or Limit)                 0.534611
# 3D Position (X)                                      0.402807
# 3D Position (Y)                                      0.231665
# 3D Position (Z)                                      0.432213
#
#                                              Orbit Apocenter  \
# l                                                  -0.072037
# b                                                  -0.133935
# Angle from l=0                                     -0.265142
# Angle from MW plane                                -0.014701
# Distance                                            0.173022
# Dist MW or M31, nearest                             0.672590
# Orbit Pericenter                                    0.694967
# Orbit Apocenter                                     1.000000
# Orbit Eccentricity                                  0.310171
# Orbit Period                                        0.610216
# Angular Radius                                     -0.107946
# Radius [pc]                                         0.278195
# V band Magnitude M$_{V}$                           -0.174790
# Distance to LG surf                                 0.633564
# Estimated Dynamical Mass                           -0.100000
# Stellar Velocity Dispersion $\sigma_{star}$        -0.615587
# Stellar Rotation Velocity $V_{rot,star}$           -0.700000
# HI Velocity Dispersion $\sigma_{gas}$              -1.000000
# HI Rotation Velocity $V_{rot,gas}$                 -1.000000
# FWHM of HI line                                          NaN
# Surface Brightness $\mu_{V}$                       -0.017417
# Heliocentric Velocity $v_{helio}$                   0.212147
# Star Formation Timescale $\tau_{90}$               -0.066580
# Mean Metallicity $\langle $[Fe/H]$\rangle $        -0.100103
# Galactocentric Velocity $V_{GSR}$                   0.344638
# Local Std of Rest Velocity $V_{LSR}$                0.218144
# Local Group Std of Rest Velocity $V_{LGSR}$         0.344313
# HI Mass $M_{HI}$ (Detected or Limit)                0.082408
# 3D Position (X)                                     0.251133
# 3D Position (Y)                                    -0.007859
# 3D Position (Z)                                     0.087105
#
#                                              Orbit Eccentricity  Orbit Period  \
# l                                                      0.288788      0.276504
# b                                                      0.048778      0.066742
# Angle from l=0                                        -0.481858     -0.190693
# Angle from MW plane                                    0.227561     -0.390920
# Distance                                              -0.580847     -0.291469
# Dist MW or M31, nearest                               -0.147411     -0.305108
# Orbit Pericenter                                      -0.279674     -0.095783
# Orbit Apocenter                                        0.310171      0.610216
# Orbit Eccentricity                                     1.000000      0.200227
# Orbit Period                                           0.200227      1.000000
# Angular Radius                                         0.348794     -0.176793
# Radius [pc]                                            0.065438     -0.257435
# V band Magnitude M$_{V}$                               0.397922      0.143019
# Distance to LG surf                                    0.252468     -0.133485
# Estimated Dynamical Mass                              -0.100000           NaN
# Stellar Velocity Dispersion $\sigma_{star}$           -0.615587           NaN
# Stellar Rotation Velocity $V_{rot,star}$               0.564288           NaN
# HI Velocity Dispersion $\sigma_{gas}$                 -0.632456           NaN
# HI Rotation Velocity $V_{rot,gas}$                    -1.000000           NaN
# FWHM of HI line                                             NaN           NaN
# Surface Brightness $\mu_{V}$                          -0.012900      0.714286
# Heliocentric Velocity $v_{helio}$                      0.491899      0.247900
# Star Formation Timescale $\tau_{90}$                   0.214064     -1.000000
# Mean Metallicity $\langle $[Fe/H]$\rangle $           -0.452013     -0.800000
# Galactocentric Velocity $V_{GSR}$                      0.389799      0.123950
# Local Std of Rest Velocity $V_{LSR}$                   0.498397      0.362316
# Local Group Std of Rest Velocity $V_{LGSR}$            0.213460      0.085812
# HI Mass $M_{HI}$ (Detected or Limit)                  -0.615145     -0.190693
# 3D Position (X)                                       -0.165844     -0.047673
# 3D Position (Y)                                       -0.332056      0.247900
# 3D Position (Z)                                       -0.533534     -0.409989
#
#                                              ...  \
# l                                            ...
# b                                            ...
# Angle from l=0                               ...
# Angle from MW plane                          ...
# Distance                                     ...
# Dist MW or M31, nearest                      ...
# Orbit Pericenter                             ...
# Orbit Apocenter                              ...
# Orbit Eccentricity                           ...
# Orbit Period                                 ...
# Angular Radius                               ...
# Radius [pc]                                  ...
# V band Magnitude M$_{V}$                     ...
# Distance to LG surf                          ...
# Estimated Dynamical Mass                     ...
# Stellar Velocity Dispersion $\sigma_{star}$  ...
# Stellar Rotation Velocity $V_{rot,star}$     ...
# HI Velocity Dispersion $\sigma_{gas}$        ...
# HI Rotation Velocity $V_{rot,gas}$           ...
# FWHM of HI line                              ...
# Surface Brightness $\mu_{V}$                 ...
# Heliocentric Velocity $v_{helio}$            ...
# Star Formation Timescale $\tau_{90}$         ...
# Mean Metallicity $\langle $[Fe/H]$\rangle $  ...
# Galactocentric Velocity $V_{GSR}$            ...
# Local Std of Rest Velocity $V_{LSR}$         ...
# Local Group Std of Rest Velocity $V_{LGSR}$  ...
# HI Mass $M_{HI}$ (Detected or Limit)         ...
# 3D Position (X)                              ...
# 3D Position (Y)                              ...
# 3D Position (Z)                              ...
#
#                                              Heliocentric Velocity $v_{helio}$  \
# l                                                                     0.389915
# b                                                                     0.235771
# Angle from l=0                                                       -0.240977
# Angle from MW plane                                                   0.189342
# Distance                                                              0.141724
# Dist MW or M31, nearest                                               0.317009
# Orbit Pericenter                                                     -0.225959
# Orbit Apocenter                                                       0.212147
# Orbit Eccentricity                                                    0.491899
# Orbit Period                                                          0.247900
# Angular Radius                                                       -0.015836
# Radius [pc]                                                           0.189744
# V band Magnitude M$_{V}$                                             -0.165632
# Distance to LG surf                                                   0.492403
# Estimated Dynamical Mass                                             -0.257143
# Stellar Velocity Dispersion $\sigma_{star}$                           0.153897
# Stellar Rotation Velocity $V_{rot,star}$                              0.395797
# HI Velocity Dispersion $\sigma_{gas}$                                 0.138352
# HI Rotation Velocity $V_{rot,gas}$                                    0.136081
# FWHM of HI line                                                       0.357576
# Surface Brightness $\mu_{V}$                                         -0.287359
# Heliocentric Velocity $v_{helio}$                                     1.000000
# Star Formation Timescale $\tau_{90}$                                 -0.220079
# Mean Metallicity $\langle $[Fe/H]$\rangle $                          -0.095439
# Galactocentric Velocity $V_{GSR}$                                     0.849438
# Local Std of Rest Velocity $V_{LSR}$                                  0.999109
# Local Group Std of Rest Velocity $V_{LGSR}$                           0.738089
# HI Mass $M_{HI}$ (Detected or Limit)                                  0.194317
# 3D Position (X)                                                      -0.515966
# 3D Position (Y)                                                      -0.051543
# 3D Position (Z)                                                      -0.367084
#
#                                              Star Formation Timescale $\tau_{90}$  \
# l                                                                       -0.138434
# b                                                                        0.038905
# Angle from l=0                                                          -0.196882
# Angle from MW plane                                                     -0.030914
# Distance                                                                -0.281780
# Dist MW or M31, nearest                                                 -0.425407
# Orbit Pericenter                                                        -0.040905
# Orbit Apocenter                                                         -0.066580
# Orbit Eccentricity                                                       0.214064
# Orbit Period                                                            -1.000000
# Angular Radius                                                          -0.002476
# Radius [pc]                                                             -0.237083
# V band Magnitude M$_{V}$                                                 0.562934
# Distance to LG surf                                                     -0.353187
# Estimated Dynamical Mass                                                      NaN
# Stellar Velocity Dispersion $\sigma_{star}$                                   NaN
# Stellar Rotation Velocity $V_{rot,star}$                                -0.702935
# HI Velocity Dispersion $\sigma_{gas}$                                   -0.052539
# HI Rotation Velocity $V_{rot,gas}$                                      -0.214286
# FWHM of HI line                                                          1.000000
# Surface Brightness $\mu_{V}$                                             0.471029
# Heliocentric Velocity $v_{helio}$                                       -0.220079
# Star Formation Timescale $\tau_{90}$                                     1.000000
# Mean Metallicity $\langle $[Fe/H]$\rangle $                             -0.652316
# Galactocentric Velocity $V_{GSR}$                                       -0.094932
# Local Std of Rest Velocity $V_{LSR}$                                    -0.210636
# Local Group Std of Rest Velocity $V_{LGSR}$                             -0.112642
# HI Mass $M_{HI}$ (Detected or Limit)                                    -0.587200
# 3D Position (X)                                                          0.100067
# 3D Position (Y)                                                         -0.286166
# 3D Position (Z)                                                         -0.000538
#
#                                              Mean Metallicity $\langle $[Fe/H]$\rangle $  \
# l                                                                               0.036802
# b                                                                              -0.360211
# Angle from l=0                                                                  0.146984
# Angle from MW plane                                                            -0.021189
# Distance                                                                        0.418910
# Dist MW or M31, nearest                                                         0.399333
# Orbit Pericenter                                                                0.218895
# Orbit Apocenter                                                                -0.100103
# Orbit Eccentricity                                                             -0.452013
# Orbit Period                                                                   -0.800000
# Angular Radius                                                                 -0.017130
# Radius [pc]                                                                     0.566434
# V band Magnitude M$_{V}$                                                       -0.897764
# Distance to LG surf                                                             0.148832
# Estimated Dynamical Mass                                                             NaN
# Stellar Velocity Dispersion $\sigma_{star}$                                          NaN
# Stellar Rotation Velocity $V_{rot,star}$                                        0.800000
# HI Velocity Dispersion $\sigma_{gas}$                                           0.239525
# HI Rotation Velocity $V_{rot,gas}$                                              1.000000
# FWHM of HI line                                                                      NaN
# Surface Brightness $\mu_{V}$                                                   -0.862488
# Heliocentric Velocity $v_{helio}$                                              -0.095439
# Star Formation Timescale $\tau_{90}$                                           -0.652316
# Mean Metallicity $\langle $[Fe/H]$\rangle $                                     1.000000
# Galactocentric Velocity $V_{GSR}$                                              -0.120801
# Local Std of Rest Velocity $V_{LSR}$                                           -0.119466
# Local Group Std of Rest Velocity $V_{LGSR}$                                    -0.018910
# HI Mass $M_{HI}$ (Detected or Limit)                                            0.674305
# 3D Position (X)                                                                 0.152337
# 3D Position (Y)                                                                 0.163043
# 3D Position (Z)                                                                -0.060444
#
#                                              Galactocentric Velocity $V_{GSR}$  \
# l                                                                    -0.027207
# b                                                                     0.256302
# Angle from l=0                                                       -0.278825
# Angle from MW plane                                                   0.121700
# Distance                                                              0.327821
# Dist MW or M31, nearest                                               0.485892
# Orbit Pericenter                                                     -0.007943
# Orbit Apocenter                                                       0.344638
# Orbit Eccentricity                                                    0.389799
# Orbit Period                                                          0.123950
# Angular Radius                                                       -0.123065
# Radius [pc]                                                           0.271111
# V band Magnitude M$_{V}$                                             -0.286105
# Distance to LG surf                                                   0.590059
# Estimated Dynamical Mass                                             -0.085714
# Stellar Velocity Dispersion $\sigma_{star}$                           0.666886
# Stellar Rotation Velocity $V_{rot,star}$                              0.364274
# HI Velocity Dispersion $\sigma_{gas}$                                 0.181946
# HI Rotation Velocity $V_{rot,gas}$                                    0.367589
# FWHM of HI line                                                       0.442424
# Surface Brightness $\mu_{V}$                                         -0.354506
# Heliocentric Velocity $v_{helio}$                                     0.849438
# Star Formation Timescale $\tau_{90}$                                 -0.094932
# Mean Metallicity $\langle $[Fe/H]$\rangle $                          -0.120801
# Galactocentric Velocity $V_{GSR}$                                     1.000000
# Local Std of Rest Velocity $V_{LSR}$                                  0.861561
# Local Group Std of Rest Velocity $V_{LGSR}$                           0.963951
# HI Mass $M_{HI}$ (Detected or Limit)                                  0.342189
# 3D Position (X)                                                      -0.379840
# 3D Position (Y)                                                      -0.283872
# 3D Position (Z)                                                      -0.029438
#
#                                              Local Std of Rest Velocity $V_{LSR}$  \
# l                                                                        0.375235
# b                                                                        0.251366
# Angle from l=0                                                          -0.252054
# Angle from MW plane                                                      0.195526
# Distance                                                                 0.150348
# Dist MW or M31, nearest                                                  0.325436
# Orbit Pericenter                                                        -0.228634
# Orbit Apocenter                                                          0.218144
# Orbit Eccentricity                                                       0.498397
# Orbit Period                                                             0.362316
# Angular Radius                                                          -0.023310
# Radius [pc]                                                              0.198632
# V band Magnitude M$_{V}$                                                -0.168884
# Distance to LG surf                                                      0.501553
# Estimated Dynamical Mass                                                -0.257143
# Stellar Velocity Dispersion $\sigma_{star}$                              0.153897
# Stellar Rotation Velocity $V_{rot,star}$                                 0.427321
# HI Velocity Dispersion $\sigma_{gas}$                                    0.131623
# HI Rotation Velocity $V_{rot,gas}$                                       0.136081
# FWHM of HI line                                                          0.309091
# Surface Brightness $\mu_{V}$                                            -0.289790
# Heliocentric Velocity $v_{helio}$                                        0.999109
# Star Formation Timescale $\tau_{90}$                                    -0.210636
# Mean Metallicity $\langle $[Fe/H]$\rangle $                             -0.119466
# Galactocentric Velocity $V_{GSR}$                                        0.861561
# Local Std of Rest Velocity $V_{LSR}$                                     1.000000
# Local Group Std of Rest Velocity $V_{LGSR}$                              0.749782
# HI Mass $M_{HI}$ (Detected or Limit)                                     0.199442
# 3D Position (X)                                                         -0.520829
# 3D Position (Y)                                                         -0.074115
# 3D Position (Z)                                                         -0.355159
#
#                                              Local Group Std of Rest Velocity $V_{LGSR}$  \
# l                                                                              -0.130419
# b                                                                               0.159642
# Angle from l=0                                                                 -0.176639
# Angle from MW plane                                                             0.034427
# Distance                                                                        0.387152
# Dist MW or M31, nearest                                                         0.511009
# Orbit Pericenter                                                                0.134538
# Orbit Apocenter                                                                 0.344313
# Orbit Eccentricity                                                              0.213460
# Orbit Period                                                                    0.085812
# Angular Radius                                                                 -0.159573
# Radius [pc]                                                                     0.275897
# V band Magnitude M$_{V}$                                                       -0.316446
# Distance to LG surf                                                             0.553588
# Estimated Dynamical Mass                                                       -0.257143
# Stellar Velocity Dispersion $\sigma_{star}$                                     0.564288
# Stellar Rotation Velocity $V_{rot,star}$                                        0.448337
# HI Velocity Dispersion $\sigma_{gas}$                                           0.243342
# HI Rotation Velocity $V_{rot,gas}$                                              0.330322
# FWHM of HI line                                                                 0.418182
# Surface Brightness $\mu_{V}$                                                   -0.352292
# Heliocentric Velocity $v_{helio}$                                               0.738089
# Star Formation Timescale $\tau_{90}$                                           -0.112642
# Mean Metallicity $\langle $[Fe/H]$\rangle $                                    -0.018910
# Galactocentric Velocity $V_{GSR}$                                               0.963951
# Local Std of Rest Velocity $V_{LSR}$                                            0.749782
# Local Group Std of Rest Velocity $V_{LGSR}$                                     1.000000
# HI Mass $M_{HI}$ (Detected or Limit)                                            0.376966
# 3D Position (X)                                                                -0.260448
# 3D Position (Y)                                                                -0.219324
# 3D Position (Z)                                                                 0.091441
#
#                                              HI Mass $M_{HI}$ (Detected or Limit)  \
# l                                                                       -0.242054
# b                                                                        0.197306
# Angle from l=0                                                           0.110675
# Angle from MW plane                                                     -0.121744
# Distance                                                                 0.874710
# Dist MW or M31, nearest                                                  0.781502
# Orbit Pericenter                                                         0.534611
# Orbit Apocenter                                                          0.082408
# Orbit Eccentricity                                                      -0.615145
# Orbit Period                                                            -0.190693
# Angular Radius                                                          -0.379945
# Radius [pc]                                                              0.523776
# V band Magnitude M$_{V}$                                                -0.838461
# Distance to LG surf                                                      0.648829
# Estimated Dynamical Mass                                                 0.885714
# Stellar Velocity Dispersion $\sigma_{star}$                             -0.461690
# Stellar Rotation Velocity $V_{rot,star}$                                 0.532400
# HI Velocity Dispersion $\sigma_{gas}$                                    0.100813
# HI Rotation Velocity $V_{rot,gas}$                                       0.796385
# FWHM of HI line                                                          0.871967
# Surface Brightness $\mu_{V}$                                            -0.707635
# Heliocentric Velocity $v_{helio}$                                        0.194317
# Star Formation Timescale $\tau_{90}$                                    -0.587200
# Mean Metallicity $\langle $[Fe/H]$\rangle $                              0.674305
# Galactocentric Velocity $V_{GSR}$                                        0.342189
# Local Std of Rest Velocity $V_{LSR}$                                     0.199442
# Local Group Std of Rest Velocity $V_{LGSR}$                              0.376966
# HI Mass $M_{HI}$ (Detected or Limit)                                     1.000000
# 3D Position (X)                                                         -0.154770
# 3D Position (Y)                                                         -0.007444
# 3D Position (Z)                                                          0.282035
#
#                                              3D Position (X)  3D Position (Y)  \
# l                                                  -0.270339         0.267120
# b                                                  -0.727885        -0.060726
# Angle from l=0                                     -0.145828         0.636414
# Angle from MW plane                                -0.342880        -0.151511
# Distance                                           -0.192254        -0.044468
# Dist MW or M31, nearest                            -0.111305        -0.088029
# Orbit Pericenter                                    0.402807         0.231665
# Orbit Apocenter                                     0.251133        -0.007859
# Orbit Eccentricity                                 -0.165844        -0.332056
# Orbit Period                                       -0.047673         0.247900
# Angular Radius                                      0.128078         0.008368
# Radius [pc]                                        -0.223268         0.143701
# V band Magnitude M$_{V}$                            0.087432         0.062507
# Distance to LG surf                                -0.222571        -0.194365
# Estimated Dynamical Mass                           -0.600000         0.200000
# Stellar Velocity Dispersion $\sigma_{star}$         0.359092         0.153897
# Stellar Rotation Velocity $V_{rot,star}$           -0.674869         0.217927
# HI Velocity Dispersion $\sigma_{gas}$               0.070667         0.048374
# HI Rotation Velocity $V_{rot,gas}$                  0.219147        -0.024852
# FWHM of HI line                                    -0.358664         0.006079
# Surface Brightness $\mu_{V}$                        0.275427         0.173359
# Heliocentric Velocity $v_{helio}$                  -0.515966        -0.051543
# Star Formation Timescale $\tau_{90}$                0.100067        -0.286166
# Mean Metallicity $\langle $[Fe/H]$\rangle $         0.152337         0.163043
# Galactocentric Velocity $V_{GSR}$                  -0.379840        -0.283872
# Local Std of Rest Velocity $V_{LSR}$               -0.520829        -0.074115
# Local Group Std of Rest Velocity $V_{LGSR}$        -0.260448        -0.219324
# HI Mass $M_{HI}$ (Detected or Limit)               -0.154770        -0.007444
# 3D Position (X)                                     1.000000        -0.006293
# 3D Position (Y)                                    -0.006293         1.000000
# 3D Position (Z)                                    -0.056866        -0.019946
#
#                                              3D Position (Z)
# l                                                  -0.498911
# b                                                   0.436200
# Angle from l=0                                      0.441875
# Angle from MW plane                                 0.020131
# Distance                                            0.356638
# Dist MW or M31, nearest                             0.212504
# Orbit Pericenter                                    0.432213
# Orbit Apocenter                                     0.087105
# Orbit Eccentricity                                 -0.533534
# Orbit Period                                       -0.409989
# Angular Radius                                     -0.258646
# Radius [pc]                                         0.068841
# V band Magnitude M$_{V}$                           -0.289751
# Distance to LG surf                                 0.035276
# Estimated Dynamical Mass                           -0.028571
# Stellar Velocity Dispersion $\sigma_{star}$         0.718185
# Stellar Rotation Velocity $V_{rot,star}$            0.186292
# HI Velocity Dispersion $\sigma_{gas}$              -0.048794
# HI Rotation Velocity $V_{rot,gas}$                 -0.120870
# FWHM of HI line                                     0.310032
# Surface Brightness $\mu_{V}$                       -0.174945
# Heliocentric Velocity $v_{helio}$                  -0.367084
# Star Formation Timescale $\tau_{90}$               -0.000538
# Mean Metallicity $\langle $[Fe/H]$\rangle $        -0.060444
# Galactocentric Velocity $V_{GSR}$                  -0.029438
# Local Std of Rest Velocity $V_{LSR}$               -0.355159
# Local Group Std of Rest Velocity $V_{LGSR}$         0.091441
# HI Mass $M_{HI}$ (Detected or Limit)                0.282035
# 3D Position (X)                                    -0.056866
# 3D Position (Y)                                    -0.019946
# 3D Position (Z)                                     1.000000
#
# [31 rows x 31 columns]

# %%
#Plot the Spearman correlation matrix as a heatmap
sb.set(font_scale=0.5) 
ax = sb.heatmap(
    spearman_matrix, 
    vmin=-1, vmax=1, center=0,
    #cmap=sb.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
col1 = 'l'
col2 =  'b'
overlap = galaxies[galaxies[col1].notna() & galaxies[col2].notna()][col1].count()
print(col1,col2,overlap)
# Out:
# l b 143

# %%
#Calculate the number of pairwise values for each pair of features since we have so much missing data
n_overlap = np.zeros((len(cols),len(cols)))
label = np.chararray((len(cols),len(cols)),itemsize=100)

for i, col1 in enumerate(cols):
    for j, col2 in enumerate(cols):
        n_overlap[i][j] = int(galaxies[galaxies[col1].notna() & galaxies[col2].notna()][col1].count())
        label[i][j] = str(col1)+'&'+str(col2)
        #print(str(col1[:3]),str(col2[:3]))
        #print(sum(galaxies[galaxies[col1].notna() & galaxies[col2].notna()][col1].notna()))
        print(i,col1,j,col2,int(n_overlap[i][j]))
# Out:
# 0 l 0 l 143
# 0 l 1 b 143
# 0 l 2 Angle from l=0 143
# 0 l 3 Angle from MW plane 143
# 0 l 4 Distance 143
# 0 l 5 Dist MW or M31, nearest 137
# 0 l 6 Orbit Pericenter 42
# 0 l 7 Orbit Apocenter 42
# 0 l 8 Orbit Eccentricity 42
# 0 l 9 Orbit Period 11
# 0 l 10 Angular Radius 136
# 0 l 11 Radius [pc] 38
# 0 l 12 V band Magnitude M$_{V}$ 138
# 0 l 13 Distance to LG surf 137
# 0 l 14 Estimated Dynamical Mass 6
# 0 l 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 0 l 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 0 l 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 0 l 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 0 l 19 FWHM of HI line 10
# 0 l 20 Surface Brightness $\mu_{V}$ 100
# 0 l 21 Heliocentric Velocity $v_{helio}$ 125
# 0 l 22 Star Formation Timescale $\tau_{90}$ 49
# 0 l 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 0 l 24 Galactocentric Velocity $V_{GSR}$ 125
# 0 l 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 0 l 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 0 l 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 0 l 28 3D Position (X) 143
# 0 l 29 3D Position (Y) 143
# 0 l 30 3D Position (Z) 143
# 1 b 0 l 143
# 1 b 1 b 143
# 1 b 2 Angle from l=0 143
# 1 b 3 Angle from MW plane 143
# 1 b 4 Distance 143
# 1 b 5 Dist MW or M31, nearest 137
# 1 b 6 Orbit Pericenter 42
# 1 b 7 Orbit Apocenter 42
# 1 b 8 Orbit Eccentricity 42
# 1 b 9 Orbit Period 11
# 1 b 10 Angular Radius 136
# 1 b 11 Radius [pc] 38
# 1 b 12 V band Magnitude M$_{V}$ 138
# 1 b 13 Distance to LG surf 137
# 1 b 14 Estimated Dynamical Mass 6
# 1 b 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 1 b 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 1 b 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 1 b 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 1 b 19 FWHM of HI line 10
# 1 b 20 Surface Brightness $\mu_{V}$ 100
# 1 b 21 Heliocentric Velocity $v_{helio}$ 125
# 1 b 22 Star Formation Timescale $\tau_{90}$ 49
# 1 b 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 1 b 24 Galactocentric Velocity $V_{GSR}$ 125
# 1 b 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 1 b 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 1 b 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 1 b 28 3D Position (X) 143
# 1 b 29 3D Position (Y) 143
# 1 b 30 3D Position (Z) 143
# 2 Angle from l=0 0 l 143
# 2 Angle from l=0 1 b 143
# 2 Angle from l=0 2 Angle from l=0 143
# 2 Angle from l=0 3 Angle from MW plane 143
# 2 Angle from l=0 4 Distance 143
# 2 Angle from l=0 5 Dist MW or M31, nearest 137
# 2 Angle from l=0 6 Orbit Pericenter 42
# 2 Angle from l=0 7 Orbit Apocenter 42
# 2 Angle from l=0 8 Orbit Eccentricity 42
# 2 Angle from l=0 9 Orbit Period 11
# 2 Angle from l=0 10 Angular Radius 136
# 2 Angle from l=0 11 Radius [pc] 38
# 2 Angle from l=0 12 V band Magnitude M$_{V}$ 138
# 2 Angle from l=0 13 Distance to LG surf 137
# 2 Angle from l=0 14 Estimated Dynamical Mass 6
# 2 Angle from l=0 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 2 Angle from l=0 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 2 Angle from l=0 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 2 Angle from l=0 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 2 Angle from l=0 19 FWHM of HI line 10
# 2 Angle from l=0 20 Surface Brightness $\mu_{V}$ 100
# 2 Angle from l=0 21 Heliocentric Velocity $v_{helio}$ 125
# 2 Angle from l=0 22 Star Formation Timescale $\tau_{90}$ 49
# 2 Angle from l=0 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 2 Angle from l=0 24 Galactocentric Velocity $V_{GSR}$ 125
# 2 Angle from l=0 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 2 Angle from l=0 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 2 Angle from l=0 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 2 Angle from l=0 28 3D Position (X) 143
# 2 Angle from l=0 29 3D Position (Y) 143
# 2 Angle from l=0 30 3D Position (Z) 143
# 3 Angle from MW plane 0 l 143
# 3 Angle from MW plane 1 b 143
# 3 Angle from MW plane 2 Angle from l=0 143
# 3 Angle from MW plane 3 Angle from MW plane 143
# 3 Angle from MW plane 4 Distance 143
# 3 Angle from MW plane 5 Dist MW or M31, nearest 137
# 3 Angle from MW plane 6 Orbit Pericenter 42
# 3 Angle from MW plane 7 Orbit Apocenter 42
# 3 Angle from MW plane 8 Orbit Eccentricity 42
# 3 Angle from MW plane 9 Orbit Period 11
# 3 Angle from MW plane 10 Angular Radius 136
# 3 Angle from MW plane 11 Radius [pc] 38
# 3 Angle from MW plane 12 V band Magnitude M$_{V}$ 138
# 3 Angle from MW plane 13 Distance to LG surf 137
# 3 Angle from MW plane 14 Estimated Dynamical Mass 6
# 3 Angle from MW plane 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 3 Angle from MW plane 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 3 Angle from MW plane 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 3 Angle from MW plane 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 3 Angle from MW plane 19 FWHM of HI line 10
# 3 Angle from MW plane 20 Surface Brightness $\mu_{V}$ 100
# 3 Angle from MW plane 21 Heliocentric Velocity $v_{helio}$ 125
# 3 Angle from MW plane 22 Star Formation Timescale $\tau_{90}$ 49
# 3 Angle from MW plane 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 3 Angle from MW plane 24 Galactocentric Velocity $V_{GSR}$ 125
# 3 Angle from MW plane 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 3 Angle from MW plane 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 3 Angle from MW plane 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 3 Angle from MW plane 28 3D Position (X) 143
# 3 Angle from MW plane 29 3D Position (Y) 143
# 3 Angle from MW plane 30 3D Position (Z) 143
# 4 Distance 0 l 143
# 4 Distance 1 b 143
# 4 Distance 2 Angle from l=0 143
# 4 Distance 3 Angle from MW plane 143
# 4 Distance 4 Distance 143
# 4 Distance 5 Dist MW or M31, nearest 137
# 4 Distance 6 Orbit Pericenter 42
# 4 Distance 7 Orbit Apocenter 42
# 4 Distance 8 Orbit Eccentricity 42
# 4 Distance 9 Orbit Period 11
# 4 Distance 10 Angular Radius 136
# 4 Distance 11 Radius [pc] 38
# 4 Distance 12 V band Magnitude M$_{V}$ 138
# 4 Distance 13 Distance to LG surf 137
# 4 Distance 14 Estimated Dynamical Mass 6
# 4 Distance 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 4 Distance 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 4 Distance 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 4 Distance 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 4 Distance 19 FWHM of HI line 10
# 4 Distance 20 Surface Brightness $\mu_{V}$ 100
# 4 Distance 21 Heliocentric Velocity $v_{helio}$ 125
# 4 Distance 22 Star Formation Timescale $\tau_{90}$ 49
# 4 Distance 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 4 Distance 24 Galactocentric Velocity $V_{GSR}$ 125
# 4 Distance 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 4 Distance 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 4 Distance 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 4 Distance 28 3D Position (X) 143
# 4 Distance 29 3D Position (Y) 143
# 4 Distance 30 3D Position (Z) 143
# 5 Dist MW or M31, nearest 0 l 137
# 5 Dist MW or M31, nearest 1 b 137
# 5 Dist MW or M31, nearest 2 Angle from l=0 137
# 5 Dist MW or M31, nearest 3 Angle from MW plane 137
# 5 Dist MW or M31, nearest 4 Distance 137
# 5 Dist MW or M31, nearest 5 Dist MW or M31, nearest 137
# 5 Dist MW or M31, nearest 6 Orbit Pericenter 41
# 5 Dist MW or M31, nearest 7 Orbit Apocenter 41
# 5 Dist MW or M31, nearest 8 Orbit Eccentricity 41
# 5 Dist MW or M31, nearest 9 Orbit Period 11
# 5 Dist MW or M31, nearest 10 Angular Radius 134
# 5 Dist MW or M31, nearest 11 Radius [pc] 38
# 5 Dist MW or M31, nearest 12 V band Magnitude M$_{V}$ 134
# 5 Dist MW or M31, nearest 13 Distance to LG surf 137
# 5 Dist MW or M31, nearest 14 Estimated Dynamical Mass 6
# 5 Dist MW or M31, nearest 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 5 Dist MW or M31, nearest 16 Stellar Rotation Velocity $V_{rot,star}$ 11
# 5 Dist MW or M31, nearest 17 HI Velocity Dispersion $\sigma_{gas}$ 34
# 5 Dist MW or M31, nearest 18 HI Rotation Velocity $V_{rot,gas}$ 20
# 5 Dist MW or M31, nearest 19 FWHM of HI line 10
# 5 Dist MW or M31, nearest 20 Surface Brightness $\mu_{V}$ 97
# 5 Dist MW or M31, nearest 21 Heliocentric Velocity $v_{helio}$ 120
# 5 Dist MW or M31, nearest 22 Star Formation Timescale $\tau_{90}$ 49
# 5 Dist MW or M31, nearest 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 5 Dist MW or M31, nearest 24 Galactocentric Velocity $V_{GSR}$ 120
# 5 Dist MW or M31, nearest 25 Local Std of Rest Velocity $V_{LSR}$ 120
# 5 Dist MW or M31, nearest 26 Local Group Std of Rest Velocity $V_{LGSR}$ 120
# 5 Dist MW or M31, nearest 27 HI Mass $M_{HI}$ (Detected or Limit) 137
# 5 Dist MW or M31, nearest 28 3D Position (X) 137
# 5 Dist MW or M31, nearest 29 3D Position (Y) 137
# 5 Dist MW or M31, nearest 30 3D Position (Z) 137
# 6 Orbit Pericenter 0 l 42
# 6 Orbit Pericenter 1 b 42
# 6 Orbit Pericenter 2 Angle from l=0 42
# 6 Orbit Pericenter 3 Angle from MW plane 42
# 6 Orbit Pericenter 4 Distance 42
# 6 Orbit Pericenter 5 Dist MW or M31, nearest 41
# 6 Orbit Pericenter 6 Orbit Pericenter 42
# 6 Orbit Pericenter 7 Orbit Apocenter 42
# 6 Orbit Pericenter 8 Orbit Eccentricity 42
# 6 Orbit Pericenter 9 Orbit Period 11
# 6 Orbit Pericenter 10 Angular Radius 41
# 6 Orbit Pericenter 11 Radius [pc] 20
# 6 Orbit Pericenter 12 V band Magnitude M$_{V}$ 42
# 6 Orbit Pericenter 13 Distance to LG surf 41
# 6 Orbit Pericenter 14 Estimated Dynamical Mass 5
# 6 Orbit Pericenter 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 6 Orbit Pericenter 16 Stellar Rotation Velocity $V_{rot,star}$ 5
# 6 Orbit Pericenter 17 HI Velocity Dispersion $\sigma_{gas}$ 4
# 6 Orbit Pericenter 18 HI Rotation Velocity $V_{rot,gas}$ 2
# 6 Orbit Pericenter 19 FWHM of HI line 0
# 6 Orbit Pericenter 20 Surface Brightness $\mu_{V}$ 32
# 6 Orbit Pericenter 21 Heliocentric Velocity $v_{helio}$ 42
# 6 Orbit Pericenter 22 Star Formation Timescale $\tau_{90}$ 24
# 6 Orbit Pericenter 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 18
# 6 Orbit Pericenter 24 Galactocentric Velocity $V_{GSR}$ 42
# 6 Orbit Pericenter 25 Local Std of Rest Velocity $V_{LSR}$ 42
# 6 Orbit Pericenter 26 Local Group Std of Rest Velocity $V_{LGSR}$ 42
# 6 Orbit Pericenter 27 HI Mass $M_{HI}$ (Detected or Limit) 41
# 6 Orbit Pericenter 28 3D Position (X) 42
# 6 Orbit Pericenter 29 3D Position (Y) 42
# 6 Orbit Pericenter 30 3D Position (Z) 42
# 7 Orbit Apocenter 0 l 42
# 7 Orbit Apocenter 1 b 42
# 7 Orbit Apocenter 2 Angle from l=0 42
# 7 Orbit Apocenter 3 Angle from MW plane 42
# 7 Orbit Apocenter 4 Distance 42
# 7 Orbit Apocenter 5 Dist MW or M31, nearest 41
# 7 Orbit Apocenter 6 Orbit Pericenter 42
# 7 Orbit Apocenter 7 Orbit Apocenter 42
# 7 Orbit Apocenter 8 Orbit Eccentricity 42
# 7 Orbit Apocenter 9 Orbit Period 11
# 7 Orbit Apocenter 10 Angular Radius 41
# 7 Orbit Apocenter 11 Radius [pc] 20
# 7 Orbit Apocenter 12 V band Magnitude M$_{V}$ 42
# 7 Orbit Apocenter 13 Distance to LG surf 41
# 7 Orbit Apocenter 14 Estimated Dynamical Mass 5
# 7 Orbit Apocenter 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 7 Orbit Apocenter 16 Stellar Rotation Velocity $V_{rot,star}$ 5
# 7 Orbit Apocenter 17 HI Velocity Dispersion $\sigma_{gas}$ 4
# 7 Orbit Apocenter 18 HI Rotation Velocity $V_{rot,gas}$ 2
# 7 Orbit Apocenter 19 FWHM of HI line 0
# 7 Orbit Apocenter 20 Surface Brightness $\mu_{V}$ 32
# 7 Orbit Apocenter 21 Heliocentric Velocity $v_{helio}$ 42
# 7 Orbit Apocenter 22 Star Formation Timescale $\tau_{90}$ 24
# 7 Orbit Apocenter 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 18
# 7 Orbit Apocenter 24 Galactocentric Velocity $V_{GSR}$ 42
# 7 Orbit Apocenter 25 Local Std of Rest Velocity $V_{LSR}$ 42
# 7 Orbit Apocenter 26 Local Group Std of Rest Velocity $V_{LGSR}$ 42
# 7 Orbit Apocenter 27 HI Mass $M_{HI}$ (Detected or Limit) 41
# 7 Orbit Apocenter 28 3D Position (X) 42
# 7 Orbit Apocenter 29 3D Position (Y) 42
# 7 Orbit Apocenter 30 3D Position (Z) 42
# 8 Orbit Eccentricity 0 l 42
# 8 Orbit Eccentricity 1 b 42
# 8 Orbit Eccentricity 2 Angle from l=0 42
# 8 Orbit Eccentricity 3 Angle from MW plane 42
# 8 Orbit Eccentricity 4 Distance 42
# 8 Orbit Eccentricity 5 Dist MW or M31, nearest 41
# 8 Orbit Eccentricity 6 Orbit Pericenter 42
# 8 Orbit Eccentricity 7 Orbit Apocenter 42
# 8 Orbit Eccentricity 8 Orbit Eccentricity 42
# 8 Orbit Eccentricity 9 Orbit Period 11
# 8 Orbit Eccentricity 10 Angular Radius 41
# 8 Orbit Eccentricity 11 Radius [pc] 20
# 8 Orbit Eccentricity 12 V band Magnitude M$_{V}$ 42
# 8 Orbit Eccentricity 13 Distance to LG surf 41
# 8 Orbit Eccentricity 14 Estimated Dynamical Mass 5
# 8 Orbit Eccentricity 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 8 Orbit Eccentricity 16 Stellar Rotation Velocity $V_{rot,star}$ 5
# 8 Orbit Eccentricity 17 HI Velocity Dispersion $\sigma_{gas}$ 4
# 8 Orbit Eccentricity 18 HI Rotation Velocity $V_{rot,gas}$ 2
# 8 Orbit Eccentricity 19 FWHM of HI line 0
# 8 Orbit Eccentricity 20 Surface Brightness $\mu_{V}$ 32
# 8 Orbit Eccentricity 21 Heliocentric Velocity $v_{helio}$ 42
# 8 Orbit Eccentricity 22 Star Formation Timescale $\tau_{90}$ 24
# 8 Orbit Eccentricity 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 18
# 8 Orbit Eccentricity 24 Galactocentric Velocity $V_{GSR}$ 42
# 8 Orbit Eccentricity 25 Local Std of Rest Velocity $V_{LSR}$ 42
# 8 Orbit Eccentricity 26 Local Group Std of Rest Velocity $V_{LGSR}$ 42
# 8 Orbit Eccentricity 27 HI Mass $M_{HI}$ (Detected or Limit) 41
# 8 Orbit Eccentricity 28 3D Position (X) 42
# 8 Orbit Eccentricity 29 3D Position (Y) 42
# 8 Orbit Eccentricity 30 3D Position (Z) 42
# 9 Orbit Period 0 l 11
# 9 Orbit Period 1 b 11
# 9 Orbit Period 2 Angle from l=0 11
# 9 Orbit Period 3 Angle from MW plane 11
# 9 Orbit Period 4 Distance 11
# 9 Orbit Period 5 Dist MW or M31, nearest 11
# 9 Orbit Period 6 Orbit Pericenter 11
# 9 Orbit Period 7 Orbit Apocenter 11
# 9 Orbit Period 8 Orbit Eccentricity 11
# 9 Orbit Period 9 Orbit Period 11
# 9 Orbit Period 10 Angular Radius 11
# 9 Orbit Period 11 Radius [pc] 11
# 9 Orbit Period 12 V band Magnitude M$_{V}$ 11
# 9 Orbit Period 13 Distance to LG surf 11
# 9 Orbit Period 14 Estimated Dynamical Mass 3
# 9 Orbit Period 15 Stellar Velocity Dispersion $\sigma_{star}$ 3
# 9 Orbit Period 16 Stellar Rotation Velocity $V_{rot,star}$ 0
# 9 Orbit Period 17 HI Velocity Dispersion $\sigma_{gas}$ 0
# 9 Orbit Period 18 HI Rotation Velocity $V_{rot,gas}$ 0
# 9 Orbit Period 19 FWHM of HI line 0
# 9 Orbit Period 20 Surface Brightness $\mu_{V}$ 6
# 9 Orbit Period 21 Heliocentric Velocity $v_{helio}$ 11
# 9 Orbit Period 22 Star Formation Timescale $\tau_{90}$ 2
# 9 Orbit Period 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 4
# 9 Orbit Period 24 Galactocentric Velocity $V_{GSR}$ 11
# 9 Orbit Period 25 Local Std of Rest Velocity $V_{LSR}$ 11
# 9 Orbit Period 26 Local Group Std of Rest Velocity $V_{LGSR}$ 11
# 9 Orbit Period 27 HI Mass $M_{HI}$ (Detected or Limit) 11
# 9 Orbit Period 28 3D Position (X) 11
# 9 Orbit Period 29 3D Position (Y) 11
# 9 Orbit Period 30 3D Position (Z) 11
# 10 Angular Radius 0 l 136
# 10 Angular Radius 1 b 136
# 10 Angular Radius 2 Angle from l=0 136
# 10 Angular Radius 3 Angle from MW plane 136
# 10 Angular Radius 4 Distance 136
# 10 Angular Radius 5 Dist MW or M31, nearest 134
# 10 Angular Radius 6 Orbit Pericenter 41
# 10 Angular Radius 7 Orbit Apocenter 41
# 10 Angular Radius 8 Orbit Eccentricity 41
# 10 Angular Radius 9 Orbit Period 11
# 10 Angular Radius 10 Angular Radius 136
# 10 Angular Radius 11 Radius [pc] 38
# 10 Angular Radius 12 V band Magnitude M$_{V}$ 135
# 10 Angular Radius 13 Distance to LG surf 134
# 10 Angular Radius 14 Estimated Dynamical Mass 6
# 10 Angular Radius 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 10 Angular Radius 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 10 Angular Radius 17 HI Velocity Dispersion $\sigma_{gas}$ 33
# 10 Angular Radius 18 HI Rotation Velocity $V_{rot,gas}$ 21
# 10 Angular Radius 19 FWHM of HI line 8
# 10 Angular Radius 20 Surface Brightness $\mu_{V}$ 98
# 10 Angular Radius 21 Heliocentric Velocity $v_{helio}$ 119
# 10 Angular Radius 22 Star Formation Timescale $\tau_{90}$ 49
# 10 Angular Radius 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 10 Angular Radius 24 Galactocentric Velocity $V_{GSR}$ 119
# 10 Angular Radius 25 Local Std of Rest Velocity $V_{LSR}$ 119
# 10 Angular Radius 26 Local Group Std of Rest Velocity $V_{LGSR}$ 119
# 10 Angular Radius 27 HI Mass $M_{HI}$ (Detected or Limit) 136
# 10 Angular Radius 28 3D Position (X) 136
# 10 Angular Radius 29 3D Position (Y) 136
# 10 Angular Radius 30 3D Position (Z) 136
# 11 Radius [pc] 0 l 38
# 11 Radius [pc] 1 b 38
# 11 Radius [pc] 2 Angle from l=0 38
# 11 Radius [pc] 3 Angle from MW plane 38
# 11 Radius [pc] 4 Distance 38
# 11 Radius [pc] 5 Dist MW or M31, nearest 38
# 11 Radius [pc] 6 Orbit Pericenter 20
# 11 Radius [pc] 7 Orbit Apocenter 20
# 11 Radius [pc] 8 Orbit Eccentricity 20
# 11 Radius [pc] 9 Orbit Period 11
# 11 Radius [pc] 10 Angular Radius 38
# 11 Radius [pc] 11 Radius [pc] 38
# 11 Radius [pc] 12 V band Magnitude M$_{V}$ 38
# 11 Radius [pc] 13 Distance to LG surf 38
# 11 Radius [pc] 14 Estimated Dynamical Mass 6
# 11 Radius [pc] 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 11 Radius [pc] 16 Stellar Rotation Velocity $V_{rot,star}$ 0
# 11 Radius [pc] 17 HI Velocity Dispersion $\sigma_{gas}$ 1
# 11 Radius [pc] 18 HI Rotation Velocity $V_{rot,gas}$ 0
# 11 Radius [pc] 19 FWHM of HI line 0
# 11 Radius [pc] 20 Surface Brightness $\mu_{V}$ 17
# 11 Radius [pc] 21 Heliocentric Velocity $v_{helio}$ 26
# 11 Radius [pc] 22 Star Formation Timescale $\tau_{90}$ 10
# 11 Radius [pc] 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 12
# 11 Radius [pc] 24 Galactocentric Velocity $V_{GSR}$ 26
# 11 Radius [pc] 25 Local Std of Rest Velocity $V_{LSR}$ 26
# 11 Radius [pc] 26 Local Group Std of Rest Velocity $V_{LGSR}$ 26
# 11 Radius [pc] 27 HI Mass $M_{HI}$ (Detected or Limit) 38
# 11 Radius [pc] 28 3D Position (X) 38
# 11 Radius [pc] 29 3D Position (Y) 38
# 11 Radius [pc] 30 3D Position (Z) 38
# 12 V band Magnitude M$_{V}$ 0 l 138
# 12 V band Magnitude M$_{V}$ 1 b 138
# 12 V band Magnitude M$_{V}$ 2 Angle from l=0 138
# 12 V band Magnitude M$_{V}$ 3 Angle from MW plane 138
# 12 V band Magnitude M$_{V}$ 4 Distance 138
# 12 V band Magnitude M$_{V}$ 5 Dist MW or M31, nearest 134
# 12 V band Magnitude M$_{V}$ 6 Orbit Pericenter 42
# 12 V band Magnitude M$_{V}$ 7 Orbit Apocenter 42
# 12 V band Magnitude M$_{V}$ 8 Orbit Eccentricity 42
# 12 V band Magnitude M$_{V}$ 9 Orbit Period 11
# 12 V band Magnitude M$_{V}$ 10 Angular Radius 135
# 12 V band Magnitude M$_{V}$ 11 Radius [pc] 38
# 12 V band Magnitude M$_{V}$ 12 V band Magnitude M$_{V}$ 138
# 12 V band Magnitude M$_{V}$ 13 Distance to LG surf 134
# 12 V band Magnitude M$_{V}$ 14 Estimated Dynamical Mass 6
# 12 V band Magnitude M$_{V}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 12 V band Magnitude M$_{V}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 12 V band Magnitude M$_{V}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 33
# 12 V band Magnitude M$_{V}$ 18 HI Rotation Velocity $V_{rot,gas}$ 21
# 12 V band Magnitude M$_{V}$ 19 FWHM of HI line 8
# 12 V band Magnitude M$_{V}$ 20 Surface Brightness $\mu_{V}$ 99
# 12 V band Magnitude M$_{V}$ 21 Heliocentric Velocity $v_{helio}$ 121
# 12 V band Magnitude M$_{V}$ 22 Star Formation Timescale $\tau_{90}$ 49
# 12 V band Magnitude M$_{V}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 12 V band Magnitude M$_{V}$ 24 Galactocentric Velocity $V_{GSR}$ 121
# 12 V band Magnitude M$_{V}$ 25 Local Std of Rest Velocity $V_{LSR}$ 121
# 12 V band Magnitude M$_{V}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 121
# 12 V band Magnitude M$_{V}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 136
# 12 V band Magnitude M$_{V}$ 28 3D Position (X) 138
# 12 V band Magnitude M$_{V}$ 29 3D Position (Y) 138
# 12 V band Magnitude M$_{V}$ 30 3D Position (Z) 138
# 13 Distance to LG surf 0 l 137
# 13 Distance to LG surf 1 b 137
# 13 Distance to LG surf 2 Angle from l=0 137
# 13 Distance to LG surf 3 Angle from MW plane 137
# 13 Distance to LG surf 4 Distance 137
# 13 Distance to LG surf 5 Dist MW or M31, nearest 137
# 13 Distance to LG surf 6 Orbit Pericenter 41
# 13 Distance to LG surf 7 Orbit Apocenter 41
# 13 Distance to LG surf 8 Orbit Eccentricity 41
# 13 Distance to LG surf 9 Orbit Period 11
# 13 Distance to LG surf 10 Angular Radius 134
# 13 Distance to LG surf 11 Radius [pc] 38
# 13 Distance to LG surf 12 V band Magnitude M$_{V}$ 134
# 13 Distance to LG surf 13 Distance to LG surf 137
# 13 Distance to LG surf 14 Estimated Dynamical Mass 6
# 13 Distance to LG surf 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 13 Distance to LG surf 16 Stellar Rotation Velocity $V_{rot,star}$ 11
# 13 Distance to LG surf 17 HI Velocity Dispersion $\sigma_{gas}$ 34
# 13 Distance to LG surf 18 HI Rotation Velocity $V_{rot,gas}$ 20
# 13 Distance to LG surf 19 FWHM of HI line 10
# 13 Distance to LG surf 20 Surface Brightness $\mu_{V}$ 97
# 13 Distance to LG surf 21 Heliocentric Velocity $v_{helio}$ 120
# 13 Distance to LG surf 22 Star Formation Timescale $\tau_{90}$ 49
# 13 Distance to LG surf 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 13 Distance to LG surf 24 Galactocentric Velocity $V_{GSR}$ 120
# 13 Distance to LG surf 25 Local Std of Rest Velocity $V_{LSR}$ 120
# 13 Distance to LG surf 26 Local Group Std of Rest Velocity $V_{LGSR}$ 120
# 13 Distance to LG surf 27 HI Mass $M_{HI}$ (Detected or Limit) 137
# 13 Distance to LG surf 28 3D Position (X) 137
# 13 Distance to LG surf 29 3D Position (Y) 137
# 13 Distance to LG surf 30 3D Position (Z) 137
# 14 Estimated Dynamical Mass 0 l 6
# 14 Estimated Dynamical Mass 1 b 6
# 14 Estimated Dynamical Mass 2 Angle from l=0 6
# 14 Estimated Dynamical Mass 3 Angle from MW plane 6
# 14 Estimated Dynamical Mass 4 Distance 6
# 14 Estimated Dynamical Mass 5 Dist MW or M31, nearest 6
# 14 Estimated Dynamical Mass 6 Orbit Pericenter 5
# 14 Estimated Dynamical Mass 7 Orbit Apocenter 5
# 14 Estimated Dynamical Mass 8 Orbit Eccentricity 5
# 14 Estimated Dynamical Mass 9 Orbit Period 3
# 14 Estimated Dynamical Mass 10 Angular Radius 6
# 14 Estimated Dynamical Mass 11 Radius [pc] 6
# 14 Estimated Dynamical Mass 12 V band Magnitude M$_{V}$ 6
# 14 Estimated Dynamical Mass 13 Distance to LG surf 6
# 14 Estimated Dynamical Mass 14 Estimated Dynamical Mass 6
# 14 Estimated Dynamical Mass 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 14 Estimated Dynamical Mass 16 Stellar Rotation Velocity $V_{rot,star}$ 0
# 14 Estimated Dynamical Mass 17 HI Velocity Dispersion $\sigma_{gas}$ 1
# 14 Estimated Dynamical Mass 18 HI Rotation Velocity $V_{rot,gas}$ 0
# 14 Estimated Dynamical Mass 19 FWHM of HI line 0
# 14 Estimated Dynamical Mass 20 Surface Brightness $\mu_{V}$ 1
# 14 Estimated Dynamical Mass 21 Heliocentric Velocity $v_{helio}$ 6
# 14 Estimated Dynamical Mass 22 Star Formation Timescale $\tau_{90}$ 1
# 14 Estimated Dynamical Mass 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 1
# 14 Estimated Dynamical Mass 24 Galactocentric Velocity $V_{GSR}$ 6
# 14 Estimated Dynamical Mass 25 Local Std of Rest Velocity $V_{LSR}$ 6
# 14 Estimated Dynamical Mass 26 Local Group Std of Rest Velocity $V_{LGSR}$ 6
# 14 Estimated Dynamical Mass 27 HI Mass $M_{HI}$ (Detected or Limit) 6
# 14 Estimated Dynamical Mass 28 3D Position (X) 6
# 14 Estimated Dynamical Mass 29 3D Position (Y) 6
# 14 Estimated Dynamical Mass 30 3D Position (Z) 6
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 0 l 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 1 b 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 2 Angle from l=0 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 3 Angle from MW plane 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 4 Distance 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 5 Dist MW or M31, nearest 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 6 Orbit Pericenter 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 7 Orbit Apocenter 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 8 Orbit Eccentricity 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 9 Orbit Period 3
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 10 Angular Radius 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 11 Radius [pc] 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 12 V band Magnitude M$_{V}$ 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 13 Distance to LG surf 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 14 Estimated Dynamical Mass 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 0
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 0
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 18 HI Rotation Velocity $V_{rot,gas}$ 0
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 19 FWHM of HI line 0
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 20 Surface Brightness $\mu_{V}$ 0
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 21 Heliocentric Velocity $v_{helio}$ 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 22 Star Formation Timescale $\tau_{90}$ 0
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 0
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 24 Galactocentric Velocity $V_{GSR}$ 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 25 Local Std of Rest Velocity $V_{LSR}$ 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 28 3D Position (X) 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 29 3D Position (Y) 5
# 15 Stellar Velocity Dispersion $\sigma_{star}$ 30 3D Position (Z) 5
# 16 Stellar Rotation Velocity $V_{rot,star}$ 0 l 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 1 b 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 2 Angle from l=0 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 3 Angle from MW plane 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 4 Distance 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 5 Dist MW or M31, nearest 11
# 16 Stellar Rotation Velocity $V_{rot,star}$ 6 Orbit Pericenter 5
# 16 Stellar Rotation Velocity $V_{rot,star}$ 7 Orbit Apocenter 5
# 16 Stellar Rotation Velocity $V_{rot,star}$ 8 Orbit Eccentricity 5
# 16 Stellar Rotation Velocity $V_{rot,star}$ 9 Orbit Period 0
# 16 Stellar Rotation Velocity $V_{rot,star}$ 10 Angular Radius 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 11 Radius [pc] 0
# 16 Stellar Rotation Velocity $V_{rot,star}$ 12 V band Magnitude M$_{V}$ 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 13 Distance to LG surf 11
# 16 Stellar Rotation Velocity $V_{rot,star}$ 14 Estimated Dynamical Mass 0
# 16 Stellar Rotation Velocity $V_{rot,star}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 0
# 16 Stellar Rotation Velocity $V_{rot,star}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 7
# 16 Stellar Rotation Velocity $V_{rot,star}$ 18 HI Rotation Velocity $V_{rot,gas}$ 5
# 16 Stellar Rotation Velocity $V_{rot,star}$ 19 FWHM of HI line 2
# 16 Stellar Rotation Velocity $V_{rot,star}$ 20 Surface Brightness $\mu_{V}$ 11
# 16 Stellar Rotation Velocity $V_{rot,star}$ 21 Heliocentric Velocity $v_{helio}$ 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 22 Star Formation Timescale $\tau_{90}$ 9
# 16 Stellar Rotation Velocity $V_{rot,star}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 5
# 16 Stellar Rotation Velocity $V_{rot,star}$ 24 Galactocentric Velocity $V_{GSR}$ 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 25 Local Std of Rest Velocity $V_{LSR}$ 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 28 3D Position (X) 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 29 3D Position (Y) 12
# 16 Stellar Rotation Velocity $V_{rot,star}$ 30 3D Position (Z) 12
# 17 HI Velocity Dispersion $\sigma_{gas}$ 0 l 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 1 b 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 2 Angle from l=0 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 3 Angle from MW plane 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 4 Distance 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 5 Dist MW or M31, nearest 34
# 17 HI Velocity Dispersion $\sigma_{gas}$ 6 Orbit Pericenter 4
# 17 HI Velocity Dispersion $\sigma_{gas}$ 7 Orbit Apocenter 4
# 17 HI Velocity Dispersion $\sigma_{gas}$ 8 Orbit Eccentricity 4
# 17 HI Velocity Dispersion $\sigma_{gas}$ 9 Orbit Period 0
# 17 HI Velocity Dispersion $\sigma_{gas}$ 10 Angular Radius 33
# 17 HI Velocity Dispersion $\sigma_{gas}$ 11 Radius [pc] 1
# 17 HI Velocity Dispersion $\sigma_{gas}$ 12 V band Magnitude M$_{V}$ 33
# 17 HI Velocity Dispersion $\sigma_{gas}$ 13 Distance to LG surf 34
# 17 HI Velocity Dispersion $\sigma_{gas}$ 14 Estimated Dynamical Mass 1
# 17 HI Velocity Dispersion $\sigma_{gas}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 0
# 17 HI Velocity Dispersion $\sigma_{gas}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 7
# 17 HI Velocity Dispersion $\sigma_{gas}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 18 HI Rotation Velocity $V_{rot,gas}$ 20
# 17 HI Velocity Dispersion $\sigma_{gas}$ 19 FWHM of HI line 10
# 17 HI Velocity Dispersion $\sigma_{gas}$ 20 Surface Brightness $\mu_{V}$ 29
# 17 HI Velocity Dispersion $\sigma_{gas}$ 21 Heliocentric Velocity $v_{helio}$ 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 22 Star Formation Timescale $\tau_{90}$ 12
# 17 HI Velocity Dispersion $\sigma_{gas}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 8
# 17 HI Velocity Dispersion $\sigma_{gas}$ 24 Galactocentric Velocity $V_{GSR}$ 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 25 Local Std of Rest Velocity $V_{LSR}$ 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 28 3D Position (X) 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 29 3D Position (Y) 35
# 17 HI Velocity Dispersion $\sigma_{gas}$ 30 3D Position (Z) 35
# 18 HI Rotation Velocity $V_{rot,gas}$ 0 l 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 1 b 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 2 Angle from l=0 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 3 Angle from MW plane 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 4 Distance 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 5 Dist MW or M31, nearest 20
# 18 HI Rotation Velocity $V_{rot,gas}$ 6 Orbit Pericenter 2
# 18 HI Rotation Velocity $V_{rot,gas}$ 7 Orbit Apocenter 2
# 18 HI Rotation Velocity $V_{rot,gas}$ 8 Orbit Eccentricity 2
# 18 HI Rotation Velocity $V_{rot,gas}$ 9 Orbit Period 0
# 18 HI Rotation Velocity $V_{rot,gas}$ 10 Angular Radius 21
# 18 HI Rotation Velocity $V_{rot,gas}$ 11 Radius [pc] 0
# 18 HI Rotation Velocity $V_{rot,gas}$ 12 V band Magnitude M$_{V}$ 21
# 18 HI Rotation Velocity $V_{rot,gas}$ 13 Distance to LG surf 20
# 18 HI Rotation Velocity $V_{rot,gas}$ 14 Estimated Dynamical Mass 0
# 18 HI Rotation Velocity $V_{rot,gas}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 0
# 18 HI Rotation Velocity $V_{rot,gas}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 5
# 18 HI Rotation Velocity $V_{rot,gas}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 20
# 18 HI Rotation Velocity $V_{rot,gas}$ 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 19 FWHM of HI line 5
# 18 HI Rotation Velocity $V_{rot,gas}$ 20 Surface Brightness $\mu_{V}$ 18
# 18 HI Rotation Velocity $V_{rot,gas}$ 21 Heliocentric Velocity $v_{helio}$ 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 22 Star Formation Timescale $\tau_{90}$ 7
# 18 HI Rotation Velocity $V_{rot,gas}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 3
# 18 HI Rotation Velocity $V_{rot,gas}$ 24 Galactocentric Velocity $V_{GSR}$ 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 25 Local Std of Rest Velocity $V_{LSR}$ 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 28 3D Position (X) 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 29 3D Position (Y) 22
# 18 HI Rotation Velocity $V_{rot,gas}$ 30 3D Position (Z) 22
# 19 FWHM of HI line 0 l 10
# 19 FWHM of HI line 1 b 10
# 19 FWHM of HI line 2 Angle from l=0 10
# 19 FWHM of HI line 3 Angle from MW plane 10
# 19 FWHM of HI line 4 Distance 10
# 19 FWHM of HI line 5 Dist MW or M31, nearest 10
# 19 FWHM of HI line 6 Orbit Pericenter 0
# 19 FWHM of HI line 7 Orbit Apocenter 0
# 19 FWHM of HI line 8 Orbit Eccentricity 0
# 19 FWHM of HI line 9 Orbit Period 0
# 19 FWHM of HI line 10 Angular Radius 8
# 19 FWHM of HI line 11 Radius [pc] 0
# 19 FWHM of HI line 12 V band Magnitude M$_{V}$ 8
# 19 FWHM of HI line 13 Distance to LG surf 10
# 19 FWHM of HI line 14 Estimated Dynamical Mass 0
# 19 FWHM of HI line 15 Stellar Velocity Dispersion $\sigma_{star}$ 0
# 19 FWHM of HI line 16 Stellar Rotation Velocity $V_{rot,star}$ 2
# 19 FWHM of HI line 17 HI Velocity Dispersion $\sigma_{gas}$ 10
# 19 FWHM of HI line 18 HI Rotation Velocity $V_{rot,gas}$ 5
# 19 FWHM of HI line 19 FWHM of HI line 10
# 19 FWHM of HI line 20 Surface Brightness $\mu_{V}$ 6
# 19 FWHM of HI line 21 Heliocentric Velocity $v_{helio}$ 10
# 19 FWHM of HI line 22 Star Formation Timescale $\tau_{90}$ 3
# 19 FWHM of HI line 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 1
# 19 FWHM of HI line 24 Galactocentric Velocity $V_{GSR}$ 10
# 19 FWHM of HI line 25 Local Std of Rest Velocity $V_{LSR}$ 10
# 19 FWHM of HI line 26 Local Group Std of Rest Velocity $V_{LGSR}$ 10
# 19 FWHM of HI line 27 HI Mass $M_{HI}$ (Detected or Limit) 10
# 19 FWHM of HI line 28 3D Position (X) 10
# 19 FWHM of HI line 29 3D Position (Y) 10
# 19 FWHM of HI line 30 3D Position (Z) 10
# 20 Surface Brightness $\mu_{V}$ 0 l 100
# 20 Surface Brightness $\mu_{V}$ 1 b 100
# 20 Surface Brightness $\mu_{V}$ 2 Angle from l=0 100
# 20 Surface Brightness $\mu_{V}$ 3 Angle from MW plane 100
# 20 Surface Brightness $\mu_{V}$ 4 Distance 100
# 20 Surface Brightness $\mu_{V}$ 5 Dist MW or M31, nearest 97
# 20 Surface Brightness $\mu_{V}$ 6 Orbit Pericenter 32
# 20 Surface Brightness $\mu_{V}$ 7 Orbit Apocenter 32
# 20 Surface Brightness $\mu_{V}$ 8 Orbit Eccentricity 32
# 20 Surface Brightness $\mu_{V}$ 9 Orbit Period 6
# 20 Surface Brightness $\mu_{V}$ 10 Angular Radius 98
# 20 Surface Brightness $\mu_{V}$ 11 Radius [pc] 17
# 20 Surface Brightness $\mu_{V}$ 12 V band Magnitude M$_{V}$ 99
# 20 Surface Brightness $\mu_{V}$ 13 Distance to LG surf 97
# 20 Surface Brightness $\mu_{V}$ 14 Estimated Dynamical Mass 1
# 20 Surface Brightness $\mu_{V}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 0
# 20 Surface Brightness $\mu_{V}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 11
# 20 Surface Brightness $\mu_{V}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 29
# 20 Surface Brightness $\mu_{V}$ 18 HI Rotation Velocity $V_{rot,gas}$ 18
# 20 Surface Brightness $\mu_{V}$ 19 FWHM of HI line 6
# 20 Surface Brightness $\mu_{V}$ 20 Surface Brightness $\mu_{V}$ 100
# 20 Surface Brightness $\mu_{V}$ 21 Heliocentric Velocity $v_{helio}$ 100
# 20 Surface Brightness $\mu_{V}$ 22 Star Formation Timescale $\tau_{90}$ 48
# 20 Surface Brightness $\mu_{V}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 20 Surface Brightness $\mu_{V}$ 24 Galactocentric Velocity $V_{GSR}$ 100
# 20 Surface Brightness $\mu_{V}$ 25 Local Std of Rest Velocity $V_{LSR}$ 100
# 20 Surface Brightness $\mu_{V}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 100
# 20 Surface Brightness $\mu_{V}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 99
# 20 Surface Brightness $\mu_{V}$ 28 3D Position (X) 100
# 20 Surface Brightness $\mu_{V}$ 29 3D Position (Y) 100
# 20 Surface Brightness $\mu_{V}$ 30 3D Position (Z) 100
# 21 Heliocentric Velocity $v_{helio}$ 0 l 125
# 21 Heliocentric Velocity $v_{helio}$ 1 b 125
# 21 Heliocentric Velocity $v_{helio}$ 2 Angle from l=0 125
# 21 Heliocentric Velocity $v_{helio}$ 3 Angle from MW plane 125
# 21 Heliocentric Velocity $v_{helio}$ 4 Distance 125
# 21 Heliocentric Velocity $v_{helio}$ 5 Dist MW or M31, nearest 120
# 21 Heliocentric Velocity $v_{helio}$ 6 Orbit Pericenter 42
# 21 Heliocentric Velocity $v_{helio}$ 7 Orbit Apocenter 42
# 21 Heliocentric Velocity $v_{helio}$ 8 Orbit Eccentricity 42
# 21 Heliocentric Velocity $v_{helio}$ 9 Orbit Period 11
# 21 Heliocentric Velocity $v_{helio}$ 10 Angular Radius 119
# 21 Heliocentric Velocity $v_{helio}$ 11 Radius [pc] 26
# 21 Heliocentric Velocity $v_{helio}$ 12 V band Magnitude M$_{V}$ 121
# 21 Heliocentric Velocity $v_{helio}$ 13 Distance to LG surf 120
# 21 Heliocentric Velocity $v_{helio}$ 14 Estimated Dynamical Mass 6
# 21 Heliocentric Velocity $v_{helio}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 21 Heliocentric Velocity $v_{helio}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 21 Heliocentric Velocity $v_{helio}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 21 Heliocentric Velocity $v_{helio}$ 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 21 Heliocentric Velocity $v_{helio}$ 19 FWHM of HI line 10
# 21 Heliocentric Velocity $v_{helio}$ 20 Surface Brightness $\mu_{V}$ 100
# 21 Heliocentric Velocity $v_{helio}$ 21 Heliocentric Velocity $v_{helio}$ 125
# 21 Heliocentric Velocity $v_{helio}$ 22 Star Formation Timescale $\tau_{90}$ 49
# 21 Heliocentric Velocity $v_{helio}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 21 Heliocentric Velocity $v_{helio}$ 24 Galactocentric Velocity $V_{GSR}$ 125
# 21 Heliocentric Velocity $v_{helio}$ 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 21 Heliocentric Velocity $v_{helio}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 21 Heliocentric Velocity $v_{helio}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 122
# 21 Heliocentric Velocity $v_{helio}$ 28 3D Position (X) 125
# 21 Heliocentric Velocity $v_{helio}$ 29 3D Position (Y) 125
# 21 Heliocentric Velocity $v_{helio}$ 30 3D Position (Z) 125
# 22 Star Formation Timescale $\tau_{90}$ 0 l 49
# 22 Star Formation Timescale $\tau_{90}$ 1 b 49
# 22 Star Formation Timescale $\tau_{90}$ 2 Angle from l=0 49
# 22 Star Formation Timescale $\tau_{90}$ 3 Angle from MW plane 49
# 22 Star Formation Timescale $\tau_{90}$ 4 Distance 49
# 22 Star Formation Timescale $\tau_{90}$ 5 Dist MW or M31, nearest 49
# 22 Star Formation Timescale $\tau_{90}$ 6 Orbit Pericenter 24
# 22 Star Formation Timescale $\tau_{90}$ 7 Orbit Apocenter 24
# 22 Star Formation Timescale $\tau_{90}$ 8 Orbit Eccentricity 24
# 22 Star Formation Timescale $\tau_{90}$ 9 Orbit Period 2
# 22 Star Formation Timescale $\tau_{90}$ 10 Angular Radius 49
# 22 Star Formation Timescale $\tau_{90}$ 11 Radius [pc] 10
# 22 Star Formation Timescale $\tau_{90}$ 12 V band Magnitude M$_{V}$ 49
# 22 Star Formation Timescale $\tau_{90}$ 13 Distance to LG surf 49
# 22 Star Formation Timescale $\tau_{90}$ 14 Estimated Dynamical Mass 1
# 22 Star Formation Timescale $\tau_{90}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 0
# 22 Star Formation Timescale $\tau_{90}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 9
# 22 Star Formation Timescale $\tau_{90}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 12
# 22 Star Formation Timescale $\tau_{90}$ 18 HI Rotation Velocity $V_{rot,gas}$ 7
# 22 Star Formation Timescale $\tau_{90}$ 19 FWHM of HI line 3
# 22 Star Formation Timescale $\tau_{90}$ 20 Surface Brightness $\mu_{V}$ 48
# 22 Star Formation Timescale $\tau_{90}$ 21 Heliocentric Velocity $v_{helio}$ 49
# 22 Star Formation Timescale $\tau_{90}$ 22 Star Formation Timescale $\tau_{90}$ 49
# 22 Star Formation Timescale $\tau_{90}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 24
# 22 Star Formation Timescale $\tau_{90}$ 24 Galactocentric Velocity $V_{GSR}$ 49
# 22 Star Formation Timescale $\tau_{90}$ 25 Local Std of Rest Velocity $V_{LSR}$ 49
# 22 Star Formation Timescale $\tau_{90}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 49
# 22 Star Formation Timescale $\tau_{90}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 49
# 22 Star Formation Timescale $\tau_{90}$ 28 3D Position (X) 49
# 22 Star Formation Timescale $\tau_{90}$ 29 3D Position (Y) 49
# 22 Star Formation Timescale $\tau_{90}$ 30 3D Position (Z) 49
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 0 l 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 1 b 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 2 Angle from l=0 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 3 Angle from MW plane 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 4 Distance 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 5 Dist MW or M31, nearest 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 6 Orbit Pericenter 18
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 7 Orbit Apocenter 18
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 8 Orbit Eccentricity 18
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 9 Orbit Period 4
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 10 Angular Radius 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 11 Radius [pc] 12
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 12 V band Magnitude M$_{V}$ 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 13 Distance to LG surf 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 14 Estimated Dynamical Mass 1
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 15 Stellar Velocity Dispersion $\sigma_{star}$ 0
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 16 Stellar Rotation Velocity $V_{rot,star}$ 5
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 17 HI Velocity Dispersion $\sigma_{gas}$ 8
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 18 HI Rotation Velocity $V_{rot,gas}$ 3
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 19 FWHM of HI line 1
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 20 Surface Brightness $\mu_{V}$ 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 21 Heliocentric Velocity $v_{helio}$ 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 22 Star Formation Timescale $\tau_{90}$ 24
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 24 Galactocentric Velocity $V_{GSR}$ 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 25 Local Std of Rest Velocity $V_{LSR}$ 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 27 HI Mass $M_{HI}$ (Detected or Limit) 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 28 3D Position (X) 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 29 3D Position (Y) 30
# 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30 3D Position (Z) 30
# 24 Galactocentric Velocity $V_{GSR}$ 0 l 125
# 24 Galactocentric Velocity $V_{GSR}$ 1 b 125
# 24 Galactocentric Velocity $V_{GSR}$ 2 Angle from l=0 125
# 24 Galactocentric Velocity $V_{GSR}$ 3 Angle from MW plane 125
# 24 Galactocentric Velocity $V_{GSR}$ 4 Distance 125
# 24 Galactocentric Velocity $V_{GSR}$ 5 Dist MW or M31, nearest 120
# 24 Galactocentric Velocity $V_{GSR}$ 6 Orbit Pericenter 42
# 24 Galactocentric Velocity $V_{GSR}$ 7 Orbit Apocenter 42
# 24 Galactocentric Velocity $V_{GSR}$ 8 Orbit Eccentricity 42
# 24 Galactocentric Velocity $V_{GSR}$ 9 Orbit Period 11
# 24 Galactocentric Velocity $V_{GSR}$ 10 Angular Radius 119
# 24 Galactocentric Velocity $V_{GSR}$ 11 Radius [pc] 26
# 24 Galactocentric Velocity $V_{GSR}$ 12 V band Magnitude M$_{V}$ 121
# 24 Galactocentric Velocity $V_{GSR}$ 13 Distance to LG surf 120
# 24 Galactocentric Velocity $V_{GSR}$ 14 Estimated Dynamical Mass 6
# 24 Galactocentric Velocity $V_{GSR}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 24 Galactocentric Velocity $V_{GSR}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 24 Galactocentric Velocity $V_{GSR}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 24 Galactocentric Velocity $V_{GSR}$ 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 24 Galactocentric Velocity $V_{GSR}$ 19 FWHM of HI line 10
# 24 Galactocentric Velocity $V_{GSR}$ 20 Surface Brightness $\mu_{V}$ 100
# 24 Galactocentric Velocity $V_{GSR}$ 21 Heliocentric Velocity $v_{helio}$ 125
# 24 Galactocentric Velocity $V_{GSR}$ 22 Star Formation Timescale $\tau_{90}$ 49
# 24 Galactocentric Velocity $V_{GSR}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 24 Galactocentric Velocity $V_{GSR}$ 24 Galactocentric Velocity $V_{GSR}$ 125
# 24 Galactocentric Velocity $V_{GSR}$ 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 24 Galactocentric Velocity $V_{GSR}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 24 Galactocentric Velocity $V_{GSR}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 122
# 24 Galactocentric Velocity $V_{GSR}$ 28 3D Position (X) 125
# 24 Galactocentric Velocity $V_{GSR}$ 29 3D Position (Y) 125
# 24 Galactocentric Velocity $V_{GSR}$ 30 3D Position (Z) 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 0 l 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 1 b 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 2 Angle from l=0 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 3 Angle from MW plane 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 4 Distance 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 5 Dist MW or M31, nearest 120
# 25 Local Std of Rest Velocity $V_{LSR}$ 6 Orbit Pericenter 42
# 25 Local Std of Rest Velocity $V_{LSR}$ 7 Orbit Apocenter 42
# 25 Local Std of Rest Velocity $V_{LSR}$ 8 Orbit Eccentricity 42
# 25 Local Std of Rest Velocity $V_{LSR}$ 9 Orbit Period 11
# 25 Local Std of Rest Velocity $V_{LSR}$ 10 Angular Radius 119
# 25 Local Std of Rest Velocity $V_{LSR}$ 11 Radius [pc] 26
# 25 Local Std of Rest Velocity $V_{LSR}$ 12 V band Magnitude M$_{V}$ 121
# 25 Local Std of Rest Velocity $V_{LSR}$ 13 Distance to LG surf 120
# 25 Local Std of Rest Velocity $V_{LSR}$ 14 Estimated Dynamical Mass 6
# 25 Local Std of Rest Velocity $V_{LSR}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 25 Local Std of Rest Velocity $V_{LSR}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 25 Local Std of Rest Velocity $V_{LSR}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 25 Local Std of Rest Velocity $V_{LSR}$ 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 25 Local Std of Rest Velocity $V_{LSR}$ 19 FWHM of HI line 10
# 25 Local Std of Rest Velocity $V_{LSR}$ 20 Surface Brightness $\mu_{V}$ 100
# 25 Local Std of Rest Velocity $V_{LSR}$ 21 Heliocentric Velocity $v_{helio}$ 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 22 Star Formation Timescale $\tau_{90}$ 49
# 25 Local Std of Rest Velocity $V_{LSR}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 25 Local Std of Rest Velocity $V_{LSR}$ 24 Galactocentric Velocity $V_{GSR}$ 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 122
# 25 Local Std of Rest Velocity $V_{LSR}$ 28 3D Position (X) 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 29 3D Position (Y) 125
# 25 Local Std of Rest Velocity $V_{LSR}$ 30 3D Position (Z) 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 0 l 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 1 b 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 2 Angle from l=0 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 3 Angle from MW plane 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 4 Distance 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 5 Dist MW or M31, nearest 120
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 6 Orbit Pericenter 42
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 7 Orbit Apocenter 42
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 8 Orbit Eccentricity 42
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 9 Orbit Period 11
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 10 Angular Radius 119
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 11 Radius [pc] 26
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 12 V band Magnitude M$_{V}$ 121
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 13 Distance to LG surf 120
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 14 Estimated Dynamical Mass 6
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 19 FWHM of HI line 10
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 20 Surface Brightness $\mu_{V}$ 100
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 21 Heliocentric Velocity $v_{helio}$ 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 22 Star Formation Timescale $\tau_{90}$ 49
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 24 Galactocentric Velocity $V_{GSR}$ 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 27 HI Mass $M_{HI}$ (Detected or Limit) 122
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 28 3D Position (X) 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 29 3D Position (Y) 125
# 26 Local Group Std of Rest Velocity $V_{LGSR}$ 30 3D Position (Z) 125
# 27 HI Mass $M_{HI}$ (Detected or Limit) 0 l 139
# 27 HI Mass $M_{HI}$ (Detected or Limit) 1 b 139
# 27 HI Mass $M_{HI}$ (Detected or Limit) 2 Angle from l=0 139
# 27 HI Mass $M_{HI}$ (Detected or Limit) 3 Angle from MW plane 139
# 27 HI Mass $M_{HI}$ (Detected or Limit) 4 Distance 139
# 27 HI Mass $M_{HI}$ (Detected or Limit) 5 Dist MW or M31, nearest 137
# 27 HI Mass $M_{HI}$ (Detected or Limit) 6 Orbit Pericenter 41
# 27 HI Mass $M_{HI}$ (Detected or Limit) 7 Orbit Apocenter 41
# 27 HI Mass $M_{HI}$ (Detected or Limit) 8 Orbit Eccentricity 41
# 27 HI Mass $M_{HI}$ (Detected or Limit) 9 Orbit Period 11
# 27 HI Mass $M_{HI}$ (Detected or Limit) 10 Angular Radius 136
# 27 HI Mass $M_{HI}$ (Detected or Limit) 11 Radius [pc] 38
# 27 HI Mass $M_{HI}$ (Detected or Limit) 12 V band Magnitude M$_{V}$ 136
# 27 HI Mass $M_{HI}$ (Detected or Limit) 13 Distance to LG surf 137
# 27 HI Mass $M_{HI}$ (Detected or Limit) 14 Estimated Dynamical Mass 6
# 27 HI Mass $M_{HI}$ (Detected or Limit) 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 27 HI Mass $M_{HI}$ (Detected or Limit) 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 27 HI Mass $M_{HI}$ (Detected or Limit) 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 27 HI Mass $M_{HI}$ (Detected or Limit) 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 27 HI Mass $M_{HI}$ (Detected or Limit) 19 FWHM of HI line 10
# 27 HI Mass $M_{HI}$ (Detected or Limit) 20 Surface Brightness $\mu_{V}$ 99
# 27 HI Mass $M_{HI}$ (Detected or Limit) 21 Heliocentric Velocity $v_{helio}$ 122
# 27 HI Mass $M_{HI}$ (Detected or Limit) 22 Star Formation Timescale $\tau_{90}$ 49
# 27 HI Mass $M_{HI}$ (Detected or Limit) 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 27 HI Mass $M_{HI}$ (Detected or Limit) 24 Galactocentric Velocity $V_{GSR}$ 122
# 27 HI Mass $M_{HI}$ (Detected or Limit) 25 Local Std of Rest Velocity $V_{LSR}$ 122
# 27 HI Mass $M_{HI}$ (Detected or Limit) 26 Local Group Std of Rest Velocity $V_{LGSR}$ 122
# 27 HI Mass $M_{HI}$ (Detected or Limit) 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 27 HI Mass $M_{HI}$ (Detected or Limit) 28 3D Position (X) 139
# 27 HI Mass $M_{HI}$ (Detected or Limit) 29 3D Position (Y) 139
# 27 HI Mass $M_{HI}$ (Detected or Limit) 30 3D Position (Z) 139
# 28 3D Position (X) 0 l 143
# 28 3D Position (X) 1 b 143
# 28 3D Position (X) 2 Angle from l=0 143
# 28 3D Position (X) 3 Angle from MW plane 143
# 28 3D Position (X) 4 Distance 143
# 28 3D Position (X) 5 Dist MW or M31, nearest 137
# 28 3D Position (X) 6 Orbit Pericenter 42
# 28 3D Position (X) 7 Orbit Apocenter 42
# 28 3D Position (X) 8 Orbit Eccentricity 42
# 28 3D Position (X) 9 Orbit Period 11
# 28 3D Position (X) 10 Angular Radius 136
# 28 3D Position (X) 11 Radius [pc] 38
# 28 3D Position (X) 12 V band Magnitude M$_{V}$ 138
# 28 3D Position (X) 13 Distance to LG surf 137
# 28 3D Position (X) 14 Estimated Dynamical Mass 6
# 28 3D Position (X) 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 28 3D Position (X) 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 28 3D Position (X) 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 28 3D Position (X) 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 28 3D Position (X) 19 FWHM of HI line 10
# 28 3D Position (X) 20 Surface Brightness $\mu_{V}$ 100
# 28 3D Position (X) 21 Heliocentric Velocity $v_{helio}$ 125
# 28 3D Position (X) 22 Star Formation Timescale $\tau_{90}$ 49
# 28 3D Position (X) 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 28 3D Position (X) 24 Galactocentric Velocity $V_{GSR}$ 125
# 28 3D Position (X) 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 28 3D Position (X) 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 28 3D Position (X) 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 28 3D Position (X) 28 3D Position (X) 143
# 28 3D Position (X) 29 3D Position (Y) 143
# 28 3D Position (X) 30 3D Position (Z) 143
# 29 3D Position (Y) 0 l 143
# 29 3D Position (Y) 1 b 143
# 29 3D Position (Y) 2 Angle from l=0 143
# 29 3D Position (Y) 3 Angle from MW plane 143
# 29 3D Position (Y) 4 Distance 143
# 29 3D Position (Y) 5 Dist MW or M31, nearest 137
# 29 3D Position (Y) 6 Orbit Pericenter 42
# 29 3D Position (Y) 7 Orbit Apocenter 42
# 29 3D Position (Y) 8 Orbit Eccentricity 42
# 29 3D Position (Y) 9 Orbit Period 11
# 29 3D Position (Y) 10 Angular Radius 136
# 29 3D Position (Y) 11 Radius [pc] 38
# 29 3D Position (Y) 12 V band Magnitude M$_{V}$ 138
# 29 3D Position (Y) 13 Distance to LG surf 137
# 29 3D Position (Y) 14 Estimated Dynamical Mass 6
# 29 3D Position (Y) 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 29 3D Position (Y) 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 29 3D Position (Y) 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 29 3D Position (Y) 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 29 3D Position (Y) 19 FWHM of HI line 10
# 29 3D Position (Y) 20 Surface Brightness $\mu_{V}$ 100
# 29 3D Position (Y) 21 Heliocentric Velocity $v_{helio}$ 125
# 29 3D Position (Y) 22 Star Formation Timescale $\tau_{90}$ 49
# 29 3D Position (Y) 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 29 3D Position (Y) 24 Galactocentric Velocity $V_{GSR}$ 125
# 29 3D Position (Y) 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 29 3D Position (Y) 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 29 3D Position (Y) 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 29 3D Position (Y) 28 3D Position (X) 143
# 29 3D Position (Y) 29 3D Position (Y) 143
# 29 3D Position (Y) 30 3D Position (Z) 143
# 30 3D Position (Z) 0 l 143
# 30 3D Position (Z) 1 b 143
# 30 3D Position (Z) 2 Angle from l=0 143
# 30 3D Position (Z) 3 Angle from MW plane 143
# 30 3D Position (Z) 4 Distance 143
# 30 3D Position (Z) 5 Dist MW or M31, nearest 137
# 30 3D Position (Z) 6 Orbit Pericenter 42
# 30 3D Position (Z) 7 Orbit Apocenter 42
# 30 3D Position (Z) 8 Orbit Eccentricity 42
# 30 3D Position (Z) 9 Orbit Period 11
# 30 3D Position (Z) 10 Angular Radius 136
# 30 3D Position (Z) 11 Radius [pc] 38
# 30 3D Position (Z) 12 V band Magnitude M$_{V}$ 138
# 30 3D Position (Z) 13 Distance to LG surf 137
# 30 3D Position (Z) 14 Estimated Dynamical Mass 6
# 30 3D Position (Z) 15 Stellar Velocity Dispersion $\sigma_{star}$ 5
# 30 3D Position (Z) 16 Stellar Rotation Velocity $V_{rot,star}$ 12
# 30 3D Position (Z) 17 HI Velocity Dispersion $\sigma_{gas}$ 35
# 30 3D Position (Z) 18 HI Rotation Velocity $V_{rot,gas}$ 22
# 30 3D Position (Z) 19 FWHM of HI line 10
# 30 3D Position (Z) 20 Surface Brightness $\mu_{V}$ 100
# 30 3D Position (Z) 21 Heliocentric Velocity $v_{helio}$ 125
# 30 3D Position (Z) 22 Star Formation Timescale $\tau_{90}$ 49
# 30 3D Position (Z) 23 Mean Metallicity $\langle $[Fe/H]$\rangle $ 30
# 30 3D Position (Z) 24 Galactocentric Velocity $V_{GSR}$ 125
# 30 3D Position (Z) 25 Local Std of Rest Velocity $V_{LSR}$ 125
# 30 3D Position (Z) 26 Local Group Std of Rest Velocity $V_{LGSR}$ 125
# 30 3D Position (Z) 27 HI Mass $M_{HI}$ (Detected or Limit) 139
# 30 3D Position (Z) 28 3D Position (X) 143
# 30 3D Position (Z) 29 3D Position (Y) 143
# 30 3D Position (Z) 30 3D Position (Z) 143

# %%
#Plot the correlation with the number of pairwise values that are not missing from the data overlaid on the heatmap
sb.set(font_scale=0.75)
a4_dims = (10, 7)
fig, ax = plt.subplots(figsize=a4_dims)

ax = sb.heatmap(
    spearman_matrix, 
    vmin=-1, vmax=1, center=0,
    #cmap=sb.diverging_palette(20, 220, n=200),
    square=True
);
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    horizontalalignment='right'
);


height, width = n_overlap.shape
xpos, ypos = np.meshgrid(np.arange(width), np.arange(height)+0.5)
sb.set(font_scale=0.5)

for x, y, N in zip(xpos.flat, ypos.flat, n_overlap.flat):
    ax.text(x, y, str(int(N)))

# %% [markdown]
# # Parameter Subset

# %%
Sub = pd.read_csv('./galaxysub.csv')
#These guys we don't want to include, so I'm just nuking them here
Sub = Sub[Sub.GalaxyName != 'NGC300']
Sub = Sub[Sub.GalaxyName != 'NGC55']
Sub = Sub[Sub.GalaxyName != 'Triangulum']
Sub = Sub[Sub.GalaxyName != '#TheGalaxy']
Sub = Sub[Sub.GalaxyName != '#Andromeda']
Sub = Sub[Sub.GalaxyName != '#*CanisMajor']

Sub = Sub.reset_index(drop=True)

# %%
#Read in table of possible subset data for regression
Sub
# Out:
#           GalaxyName  MHI_computed     MHI_type       V_GSR  \
# 0    SagittariusdSph           0.0  upper_limit  172.923646
# 1          TucanaIII           0.0  upper_limit -191.421092
# 2            DracoII           0.0  upper_limit -170.461213
# 3             Segue1           0.0  upper_limit  113.587537
# 4         Reticulum2           0.0  upper_limit  -91.212863
# ..               ...           ...          ...         ...
# 132          HydrusI           0.0  upper_limit  -84.947393
# 133         CarinaII           0.0  upper_limit  252.414541
# 134        CarinaIII           0.0  upper_limit   59.593891
# 135         CraterII           0.0  upper_limit  -72.443765
# 136       AquariusII           0.0  upper_limit   43.102940
#
#      min_dist_mw_or_m31    M_star           L_V  tau_90    M_V
# 0             18.587576  21.00000  2.147830e+07     NaN -13.50
# 1             23.298941       NaN  7.870458e+02     NaN  -2.41
# 2             26.126576       NaN  1.235947e+03     NaN  -2.90
# 3             27.768802   0.00034  3.404082e+02     NaN  -1.50
# 4             31.610186       NaN  1.028016e+03     NaN  -2.70
# ..                  ...       ...           ...     ...    ...
# 132           25.741743       NaN  6.546362e+03     NaN  -4.71
# 133           37.296364       NaN  5.395106e+03     NaN  -4.50
# 134           29.180644       NaN  7.798301e+02     NaN  -2.40
# 135          116.471698       NaN  1.629296e+05     NaN  -8.20
# 136          105.169370       NaN  4.742420e+03     NaN  -4.36
#
# [137 rows x 9 columns]

# %%
#Scatter plot of MHI_computed vs V_GSR
Sub.plot(kind='scatter',x='MHI_computed',y='V_GSR')
plt.xscale('log',base=10)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-337-fb58236a0676> in <module>
#       1 #Scatter plot of MHI_computed vs V_GSR
#       2 Sub.plot(kind='scatter',x='MHI_computed',y='V_GSR')
# ----> 3 plt.xscale('log',base=10)
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/pyplot.py in xscale(value, **kwargs)
#    3074 @docstring.copy(Axes.set_xscale)
#    3075 def xscale(value, **kwargs):
# -> 3076     return gca().set_xscale(value, **kwargs)
#    3077
#    3078
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_xscale(self, value, **kwargs)
#    3325         g = self.get_shared_x_axes()
#    3326         for ax in g.get_siblings(self):
# -> 3327             ax.xaxis._set_scale(value, **kwargs)
#    3328             ax._update_transScale()
#    3329             ax.stale = True
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     797
#     798     def _set_scale(self, value, **kwargs):
# --> 799         self._scale = mscale.scale_factory(value, self, **kwargs)
#     800         self._scale.set_default_locators_and_formatters(self)
#     801
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in scale_factory(scale, axis, **kwargs)
#     731     if scale not in _scale_mapping:
#     732         raise ValueError("Unknown scale type '%s'" % scale)
# --> 733     return _scale_mapping[scale](axis, **kwargs)
#     734
#     735 if scale_factory.__doc__:
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in __init__(self, axis, **kwargs)
#     387                               "{'basex', 'subsx', nonposx'} or "
#     388                               "{'basey', 'subsy', nonposy'}.  You passed ") +
# --> 389                              "{!r}".format(kwargs))
#     390
#     391         if base <= 0 or base == 1:
#
# ValueError: provided too many kwargs, can only pass {'basex', 'subsx', nonposx'} or {'basey', 'subsy', nonposy'}.  You passed {'base': 10}

# %%
#Scatter plot of MHI_computed vs min_dist_mw_or_m31
Sub.plot(kind='scatter',x='MHI_computed',y='min_dist_mw_or_m31')
plt.xscale('log',base=10)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-338-e08c5485542b> in <module>
#       1 #Scatter plot of MHI_computed vs min_dist_mw_or_m31
#       2 Sub.plot(kind='scatter',x='MHI_computed',y='min_dist_mw_or_m31')
# ----> 3 plt.xscale('log',base=10)
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/pyplot.py in xscale(value, **kwargs)
#    3074 @docstring.copy(Axes.set_xscale)
#    3075 def xscale(value, **kwargs):
# -> 3076     return gca().set_xscale(value, **kwargs)
#    3077
#    3078
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_xscale(self, value, **kwargs)
#    3325         g = self.get_shared_x_axes()
#    3326         for ax in g.get_siblings(self):
# -> 3327             ax.xaxis._set_scale(value, **kwargs)
#    3328             ax._update_transScale()
#    3329             ax.stale = True
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     797
#     798     def _set_scale(self, value, **kwargs):
# --> 799         self._scale = mscale.scale_factory(value, self, **kwargs)
#     800         self._scale.set_default_locators_and_formatters(self)
#     801
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in scale_factory(scale, axis, **kwargs)
#     731     if scale not in _scale_mapping:
#     732         raise ValueError("Unknown scale type '%s'" % scale)
# --> 733     return _scale_mapping[scale](axis, **kwargs)
#     734
#     735 if scale_factory.__doc__:
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in __init__(self, axis, **kwargs)
#     387                               "{'basex', 'subsx', nonposx'} or "
#     388                               "{'basey', 'subsy', nonposy'}.  You passed ") +
# --> 389                              "{!r}".format(kwargs))
#     390
#     391         if base <= 0 or base == 1:
#
# ValueError: provided too many kwargs, can only pass {'basex', 'subsx', nonposx'} or {'basey', 'subsy', nonposy'}.  You passed {'base': 10}

# %%
#Scatter plot of MHI_computed vs M_star
Sub.plot(kind='scatter',x='MHI_computed',y='M_star')
plt.xscale('log',base=10)

# %%
#Scatter plot of MHI_computed vs L_V
Sub.plot(kind='scatter',x='MHI_computed',y='L_V')
plt.xscale('log',base=10)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-339-5ac5cfc7cb21> in <module>
#       1 #Scatter plot of MHI_computed vs L_V
#       2 Sub.plot(kind='scatter',x='MHI_computed',y='L_V')
# ----> 3 plt.xscale('log',base=10)
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/pyplot.py in xscale(value, **kwargs)
#    3074 @docstring.copy(Axes.set_xscale)
#    3075 def xscale(value, **kwargs):
# -> 3076     return gca().set_xscale(value, **kwargs)
#    3077
#    3078
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_xscale(self, value, **kwargs)
#    3325         g = self.get_shared_x_axes()
#    3326         for ax in g.get_siblings(self):
# -> 3327             ax.xaxis._set_scale(value, **kwargs)
#    3328             ax._update_transScale()
#    3329             ax.stale = True
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     797
#     798     def _set_scale(self, value, **kwargs):
# --> 799         self._scale = mscale.scale_factory(value, self, **kwargs)
#     800         self._scale.set_default_locators_and_formatters(self)
#     801
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in scale_factory(scale, axis, **kwargs)
#     731     if scale not in _scale_mapping:
#     732         raise ValueError("Unknown scale type '%s'" % scale)
# --> 733     return _scale_mapping[scale](axis, **kwargs)
#     734
#     735 if scale_factory.__doc__:
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in __init__(self, axis, **kwargs)
#     387                               "{'basex', 'subsx', nonposx'} or "
#     388                               "{'basey', 'subsy', nonposy'}.  You passed ") +
# --> 389                              "{!r}".format(kwargs))
#     390
#     391         if base <= 0 or base == 1:
#
# ValueError: provided too many kwargs, can only pass {'basex', 'subsx', nonposx'} or {'basey', 'subsy', nonposy'}.  You passed {'base': 10}

# %%
#Scatter plot of MHI_computed vs tau_90
Sub.plot(kind='scatter',x='MHI_computed',y='tau_90')
plt.xscale('log',base=10)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-340-1006d79f8504> in <module>
#       1 #Scatter plot of MHI_computed vs tau_90
#       2 Sub.plot(kind='scatter',x='MHI_computed',y='tau_90')
# ----> 3 plt.xscale('log',base=10)
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/pyplot.py in xscale(value, **kwargs)
#    3074 @docstring.copy(Axes.set_xscale)
#    3075 def xscale(value, **kwargs):
# -> 3076     return gca().set_xscale(value, **kwargs)
#    3077
#    3078
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_xscale(self, value, **kwargs)
#    3325         g = self.get_shared_x_axes()
#    3326         for ax in g.get_siblings(self):
# -> 3327             ax.xaxis._set_scale(value, **kwargs)
#    3328             ax._update_transScale()
#    3329             ax.stale = True
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     797
#     798     def _set_scale(self, value, **kwargs):
# --> 799         self._scale = mscale.scale_factory(value, self, **kwargs)
#     800         self._scale.set_default_locators_and_formatters(self)
#     801
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in scale_factory(scale, axis, **kwargs)
#     731     if scale not in _scale_mapping:
#     732         raise ValueError("Unknown scale type '%s'" % scale)
# --> 733     return _scale_mapping[scale](axis, **kwargs)
#     734
#     735 if scale_factory.__doc__:
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in __init__(self, axis, **kwargs)
#     387                               "{'basex', 'subsx', nonposx'} or "
#     388                               "{'basey', 'subsy', nonposy'}.  You passed ") +
# --> 389                              "{!r}".format(kwargs))
#     390
#     391         if base <= 0 or base == 1:
#
# ValueError: provided too many kwargs, can only pass {'basex', 'subsx', nonposx'} or {'basey', 'subsy', nonposy'}.  You passed {'base': 10}

# %%
#Scatter plot of MHI_computed vs M_V
Sub.plot(kind='scatter',x='MHI_computed',y='M_V')
plt.xscale('log',base=10)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-341-dacab6b4dbde> in <module>
#       1 #Scatter plot of MHI_computed vs M_V
#       2 Sub.plot(kind='scatter',x='MHI_computed',y='M_V')
# ----> 3 plt.xscale('log',base=10)
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/pyplot.py in xscale(value, **kwargs)
#    3074 @docstring.copy(Axes.set_xscale)
#    3075 def xscale(value, **kwargs):
# -> 3076     return gca().set_xscale(value, **kwargs)
#    3077
#    3078
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_xscale(self, value, **kwargs)
#    3325         g = self.get_shared_x_axes()
#    3326         for ax in g.get_siblings(self):
# -> 3327             ax.xaxis._set_scale(value, **kwargs)
#    3328             ax._update_transScale()
#    3329             ax.stale = True
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     797
#     798     def _set_scale(self, value, **kwargs):
# --> 799         self._scale = mscale.scale_factory(value, self, **kwargs)
#     800         self._scale.set_default_locators_and_formatters(self)
#     801
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in scale_factory(scale, axis, **kwargs)
#     731     if scale not in _scale_mapping:
#     732         raise ValueError("Unknown scale type '%s'" % scale)
# --> 733     return _scale_mapping[scale](axis, **kwargs)
#     734
#     735 if scale_factory.__doc__:
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/matplotlib/scale.py in __init__(self, axis, **kwargs)
#     387                               "{'basex', 'subsx', nonposx'} or "
#     388                               "{'basey', 'subsy', nonposy'}.  You passed ") +
# --> 389                              "{!r}".format(kwargs))
#     390
#     391         if base <= 0 or base == 1:
#
# ValueError: provided too many kwargs, can only pass {'basex', 'subsx', nonposx'} or {'basey', 'subsy', nonposy'}.  You passed {'base': 10}

# %%
list(Sub.columns)

# %%
#drop
Sub.drop('MHI_type',axis=1,inplace=True)
Sub.drop('M_star',axis=1,inplace=True)
Sub.drop('L_V',axis=1,inplace=True)

# %%
list(galaxies_shortnames.columns)
# Out:
# ['Unnamed: 0',
#  'GalaxyName',
#  'RA_hr',
#  'RA_min',
#  'RA_sec',
#  'Dec_deg',
#  'Dec_arcmin',
#  'Dec_arcsec',
#  'EB-V',
#  'm-M',
#  'm-M_err_pos',
#  'm-M_err_neg',
#  'vh(km/s)',
#  'Vmag',
#  'Vmag_err_pos',
#  'Vmag_err_neg',
#  'PA',
#  'e=1-b/a',
#  'muVo',
#  "rh(')",
#  'rh_err_pos',
#  'rh_err_neg',
#  'vsig_s_x',
#  'vsig_err_pos',
#  'vsig_err_neg',
#  'vrot_s',
#  'vrot_s_err_pos',
#  'vrot_s_err_neg',
#  'MHI_x',
#  'Data',
#  'Key',
#  'vsig_g',
#  'vsig_g_err_pos',
#  'vsig_g_err_neg',
#  'vrot_g',
#  'note',
#  'M-m',
#  'Notes',
#  'ra',
#  'dec',
#  'M_V',
#  'dist_kpc',
#  'M_dyn',
#  'vh_(km/s)_err',
#  'vsig_s_upper_limit',
#  'vsig_s_err',
#  'vh(km/s)_err',
#  'orb_pericenter',
#  'orb_apocenter',
#  'orb_eccentricity',
#  'orb_period',
#  'orb_period_type',
#  'orb_pericenter_ref',
#  'orb_pericenter_0.8',
#  'orb_apocenter_0.8',
#  'orb_eccentricity_0.8',
#  'tau_50',
#  'tau_90',
#  'vsig_s_ref',
#  'vsig_s_err_pos_ref',
#  'vsig_s_err_neg_ref',
#  'M_V_ref',
#  'rh_pc_ref',
#  'rh_pc_err_pos_ref',
#  'rh_pc_err_neg_ref',
#  'vh(km/s)_ref',
#  'dist_kpc_ref',
#  'refs',
#  'M_star',
#  'M_dyn_r_h',
#  'Other names',
#  'Morphology',
#  'dist_pc',
#  'dist_mpc',
#  'vsig_s_err_pos_x',
#  'vsig_s_err_neg_x',
#  'rh_pc',
#  'rh_pc_err_neg',
#  'rh_pc_err_pos',
#  'vsig_s_y',
#  'vsig_s_err_pos_y',
#  'vsig_s_err_neg_y',
#  'gal_interference_min',
#  'gal_interference_max',
#  'Galactic Interference Range',
#  'MHI_computed',
#  'MHI_source',
#  'MHI_type',
#  '1sigma',
#  'rh_subtable',
#  'MHI_method',
#  'npix',
#  'GUU',
#  'GRU',
#  'HUU',
#  'HRU',
#  'GNV',
#  'HNV',
#  'LIT',
#  '1sigma_GUU',
#  '1sigma_GRU',
#  '1sigma_HUU',
#  '1sigma_HRU',
#  '1sigma_GNV',
#  '1sigma_HNV',
#  'm-M_err',
#  'Vmag_err',
#  'vsig_s',
#  'vsig_err',
#  'MHI_mcconnachie',
#  'vsig_g_err',
#  'GalaxyType',
#  'A_V',
#  'b_100M',
#  'b_1G',
#  'f_10G',
#  'mean_logz',
#  'Disturber',
#  'D',
#  'Theta',
#  'RA',
#  'Dec',
#  'OtherName',
#  'Subgroup',
#  'mateo_1',
#  'mateo_b',
#  'mateo_l',
#  '[Fe/H]',
#  '[Fe/H]_err',
#  'sigma_[Fe/H]',
#  'sigma_[Fe/H]_err',
#  'Ref1_Mateo98_Tab6',
#  '12 + log(O/H)',
#  'log(O/H)_err',
#  '[N/O]',
#  '[N/O]_err',
#  'Ref2_Mateo98_Tab6',
#  'Notes_Mateo98_Tab6',
#  'l',
#  'b',
#  'V_LSR',
#  'V_GSR',
#  'V_LGSR',
#  'X',
#  'Y',
#  'Z',
#  'angle_from_l=0',
#  'angle_from_MW_plane',
#  'M_dyn_calculated',
#  'M_dyn_method',
#  'MHI/M_star',
#  'MHI/M_dyn',
#  'MHI/M_V',
#  'L_V',
#  'MHI/L_V',
#  'r_ell',
#  'ell_surf_dist',
#  'mw_dist',
#  'm31_dist',
#  'r_per_mean',
#  'r_per_median',
#  'r_per_std',
#  'r_per_err1',
#  'r_per_err2',
#  'v_per_mean',
#  'v_per_median',
#  'v_per_std',
#  'n_halo_peri',
#  'n_halo_peri_err1',
#  'n_halo_peri_err2',
#  'r_apo_mean',
#  'r_apo_median',
#  'r_apo_std',
#  'r_apo_err1',
#  'r_apo_err2',
#  'v_apo_mean',
#  'v_apo_median',
#  'v_apo_std',
#  'n_halo_apo',
#  'n_halo_apo_err1',
#  'n_halo_apo_err2',
#  'ell_surf_log10_abs',
#  'min_dist_mw_or_m31',
#  'Closer_MW_M31',
#  'RA (J2000)',
#  'DE (J2000)',
#  'Distance',
#  'sigDist',
#  'MHI_y',
#  'W50',
#  'Vhelio']

# %%
Sub = pd.merge(Sub, galaxies_shortnames[['GalaxyName','rh_pc']], on="GalaxyName", how="left")

# %%
Sub[Sub['rh_pc']][['GalaxyName','rh_pc']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-356-534dbf3b9c5d> in <module>
# ----> 1 Sub[Sub['rh_pc'].isnan][['GalaxyName','rh_pc']]
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'isnan'

# %%
#Sub.drop('GalaxyName',axis=1,inplace=True)
Sub.drop('tau_90',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-350-8b656508748d> in <module>
#       1 #Sub.drop('GalaxyName',axis=1,inplace=True)
# ----> 2 Sub.drop('tau_90',axis=1,inplace=True)
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['tau_90'] not found in axis"

# %%
Sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137 entries, 0 to 136
# Data columns (total 6 columns):
# GalaxyName            137 non-null object
# MHI_computed          137 non-null float64
# V_GSR                 120 non-null float64
# min_dist_mw_or_m31    137 non-null float64
# M_V                   134 non-null float64
# rh_pc                 38 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 7.5+ KB

# %%
Sub.describe()
# Out:
#        MHI_computed       V_GSR  min_dist_mw_or_m31         M_V        rh_pc
# count  1.370000e+02  120.000000          137.000000  134.000000    38.000000
# mean   2.384336e+07  -15.843160          595.263315   -8.655448   147.684211
# std    1.005008e+08  186.137562          832.722722    4.335015   210.707317
# min    0.000000e+00 -647.615604           18.587576  -18.120000    16.000000
# 25%    0.000000e+00 -121.502747           77.757030  -12.087500    38.250000
# 50%    0.000000e+00   10.169381          160.573464   -9.050000    70.000000
# 75%    7.300000e+05  130.794320          802.760859   -4.742500   154.750000
# max    8.600000e+08  304.632503         2952.809678    0.020000  1066.000000

# %%
#Sub['MHI_log'] = np.log(Sub['MHI_computed'])
#Sub['tau_90_log'] = np.log(Sub['tau_90'])

# %%
#Sub.drop('MHI_computed',axis=1, inplace=True)
#Sub.drop('tau_90',axis=1, inplace=True)

# %%
#define x and y
#y = Sub['MHI_log']
#x = Sub.drop('MHI_log',axis=1,inplace=True)
#define x and y
y = Sub['MHI_computed']
x = Sub.drop('MHI_computed',axis=1)

# %%
# print the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
LR = LinearRegression()

# %%
RF = RandomForestRegressor(n_estimators=10, max_depth=3, n_jobs=1, verbose=2)

# %%
RF.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-297-348879a48d6f> in <module>
# ----> 1 RF.fit(x_train,y_train)
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     293         """
#     294         # Validate or convert input data
# --> 295         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     296         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     297         if sample_weight is not None:
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# ~/.pyenv/versions/jupyter3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
